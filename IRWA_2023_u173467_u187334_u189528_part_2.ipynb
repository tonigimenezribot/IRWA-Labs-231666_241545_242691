# %% [markdown]
# **Project delivery 1**

# %% [markdown]
# Part 1: Text Processing and Exploratory Data Analysis

# %%
import nltk

# %%
from collections import defaultdict
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import time
import json
import re
import pandas as pd
from sklearn.manifold import TSNE

# %% [markdown]
# ****
# **0. LOAD AND STRUCTURE**

# %% [markdown]
# For each tweet we have the following features:
#
# - docID
# - Tweet
# - ID
# - Date
# - Hashtags
# - Likes
# - Retweets
# - Url

# %%
# LOAD

# Open the file: Load data into memory
docs_path = './IRWA_data_2023/Rus_Ukr_war_data.json'
with open(docs_path) as fp:
    # Read the file
    lines = fp.readlines()

data = []
for i in lines:
    data.append(json.loads(i))
    
# STRUCTURE   

# docID | Tweet | ID | Date | Hashtags | Likes | Retweets | Url
# Create a list of dictionaries
tweet_dicts = []

for i in range(len(data)):
    doc_id = 'doc_' + str(i+1)
    tweet_text = data[i]['full_text']
    tweet_id = data[i]['id']
    tweet_date = data[i]['created_at']
    hashtags = [hashtag['text'] for hashtag in data[i]['entities']['hashtags']]
    likes = data[i]['favorite_count']
    retweets = data[i]['retweet_count']
    url = 'https://twitter.com/' + str(data[i]['user']['screen_name'])+'/status/'+str(tweet_id)

    # Create a dictionary for each tweet
    tweet_dict = {'DOC_ID': doc_id, 'Tweet Text': tweet_text, 'Tweet ID': tweet_id, 'Tweet Date': tweet_date, 'Hashtags': hashtags,
                  'Likes': likes, 'Retweets': retweets, 'URL': url}

    # Append the dictionary to the list
    tweet_dicts.append(tweet_dict)

print(tweet_dicts[400])
# Out:
# {'DOC_ID': 'doc_401', 'Tweet Text': 'Morning little buddy Zhang @ChinaAmbUN #JinPing #CCP little man #Putin has gone off the rails for everyone to see.  World has spoken my friend. You are backing a loser. Do the right thing before its too late to turn back the clock. #UkraineRussiaWar  @UKRinUN @USUN @RussiaUN https://t.co/kMwyzEHSvt', 'Tweet ID': 1575863777265942528, 'Tweet Date': 'Fri Sep 30 15:02:57 +0000 2022', 'Hashtags': ['JinPing', 'CCP', 'Putin', 'UkraineRussiaWar'], 'Likes': 1, 'Retweets': 0, 'URL': 'https://twitter.com/onestandard4all/status/1575863777265942528'}

# %% [markdown]
# ****
# **1. PRE-PROCESS THE DOCUMENTS**

# %%
def build_terms(line):
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))

    # Tweet Text and Tweet date to lowercase and tokenized
    line['Tweet Text']=  line['Tweet Text'].lower().split()
    line['Tweet Date']=  line['Tweet Date'].lower().split()
    
    # HASHTAGS
    # To lowercase
    line['Hashtags'] = [word.lower() for word in line['Hashtags']]
    
    line['Tweet Text'] = [word for word in line['Tweet Text'] if word[0] != '#']
    #EXTRA-- DELETE SYMBOLS 
    # Decided to delete the hashtags symbols as we have the list of hashtags in the dictionary
    line['Tweet Text'] = [re.sub(r"[^\w\s']+", '', word) for word in line['Tweet Text']]
    
    # DELETE PUNCTUATION
    # EXTRA IF word is a link NOT TO DELETE THE punctuation SYMBOLS
    line['Tweet Text'] = [re.sub(r"[,.;@#?!&$]+", '', word) for word in line['Tweet Text'] if not word.startswith('https')]
    
    # EXTRA-- DELETE EMPTY STRINGS "" 
    line['Tweet Text']= [word for word in line['Tweet Text'] if word != '']
    
    #DELETE STOPWORDS 
    line['Tweet Text']= [word for word in line['Tweet Text'] if word not in stop_words]
    
    # DEALING WITH STEMMING
    line['Tweet Text']= [stemmer.stem(word) for word in line['Tweet Text']]
    
    return line

# print a tweet
print(tweet_dicts[400])
# Out:
# {'DOC_ID': 'doc_401', 'Tweet Text': 'Morning little buddy Zhang @ChinaAmbUN #JinPing #CCP little man #Putin has gone off the rails for everyone to see.  World has spoken my friend. You are backing a loser. Do the right thing before its too late to turn back the clock. #UkraineRussiaWar  @UKRinUN @USUN @RussiaUN https://t.co/kMwyzEHSvt', 'Tweet ID': 1575863777265942528, 'Tweet Date': 'Fri Sep 30 15:02:57 +0000 2022', 'Hashtags': ['JinPing', 'CCP', 'Putin', 'UkraineRussiaWar'], 'Likes': 1, 'Retweets': 0, 'URL': 'https://twitter.com/onestandard4all/status/1575863777265942528'}

# %%
#PROCESS ALL THE TWEETS
for tweet in tweet_dicts:
    tweet = build_terms(tweet)

# %%
print(tweet_dicts[2])
# Out:
# {'DOC_ID': 'doc_3', 'Tweet Text': ['alert', 'poland', 'prep', 'antiradi', 'tablet', 'nuclear', 'threat'], 'Tweet ID': 1575917992390823936, 'Tweet Date': ['fri', 'sep', '30', '18:38:23', '+0000', '2022'], 'Hashtags': ['nato', 'putin', 'russia', 'russiainvadedukraine', 'ukraine', 'ukrainerussiawar'], 'Likes': 0, 'Retweets': 0, 'URL': 'https://twitter.com/NEWS_ALL_TIME/status/1575917992390823936'}

# %% [markdown]
# ****
# **PROJECT PART 2**

# %% [markdown]
# 1. Build inverted index

# %%
def create_index(lines): 
    index = defaultdict(list)
    # Create an index for each term in the tweet text
    for i, line in enumerate(lines):
        for term in line['Tweet Text']:
            # show a list in which doc_id it appears
            if i not in index[term]:
                index[term].append(i)
                      
    return index

# %%
index = create_index(tweet_dicts)
#index

# %% [markdown]
# 2. Propose test queries

# %%
# build terms for the query 
def build_terms_query(query):
    # To lowercase and tokenized
    query = query.lower().split()
    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))
    #DELETE STOPWORDS
    query = [word for word in query if word not in stop_words]
    # DEALING WITH STEMMING
    query = [stemmer.stem(word) for word in query]
    return query

# %% [markdown]
# The difference between search_union and search_intersection is that the first one returns the documents that contain at least one of the words in the query, while the second one returns the documents that contain all the words in the query. We are going to use both for a further analysis:

# %%
def search_intersection(query, index):
    "term_docs contains (for each word) the documents that contain each word in the query, "
    "then we should intersect these lists in order to obtain the documents where all "
    "the words in the query are found"
    
    query = build_terms_query(query)
    docs = None  
    for term in query:
        try:
            term_docs = set(index[term]) 
            #print(term, len(term_docs))
            if docs is None:
                docs = term_docs
            else:
                docs = docs.intersection(term_docs)
        except KeyError:
            # Term is not in index
            pass

    if docs is not None:
        docs = list(docs)
    else:
        docs = []  # No matching documents found

    return docs

# %% [markdown]
# To do the select the queries we are going to do in a better way we are going to see the most frequent words in the corpus and then we are going to select the queries.

# %%
print('Top 10 most used words:')
df = pd.DataFrame(tweet_dicts)
# terms most used by frequency 
all_words = []
for line in df['Tweet Text']:
    all_words.extend(line)
# Create a dictionary with the frequency of each word
word_freq = collections.Counter(all_words)
word_freq.most_common(10)
# Out:
# Top 10 most used words:
# [('ukrain', 945),
#  ('russian', 884),
#  ('russia', 556),
#  ('ukrainian', 466),
#  ('war', 444),
#  ('putin', 443),
#  ('forc', 273),
#  ('region', 250),
#  ('annex', 226),
#  ('amp', 222)]

# %% [markdown]
# Selection of queries for search_intersection:

# %%
# 1. "Ukraine and Russia"
query = "Ukraine and Russia"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")

# 2. "Ukraine Russia War"

query = "Ukraine Russia War"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")

# 3. "World War"
query = "World war"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")

# 4. "putin war"
query = "putin war"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")

# 5. "Annex Region"
query = "Annex Region"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")

# 6. "Putin world war"
query = "Putin world war"
docs = search_intersection(query, index)
print(query, len(docs))
#print(docs)
print("*************")
# Out:
# Ukraine and Russia 180
# *************
# Ukraine Russia War 50
# *************
# World war 21
# *************
# putin war 48
# *************
# Annex Region 60
# *************
# Putin world war 3
# *************

# %% [markdown]
# 3. Rank your results

# %%
def create_index_tfidf(lines):
    index = create_index(lines)
    tf = defaultdict(list)  # term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  # document frequencies of terms in the corpus
    idf = defaultdict(float)

    # Total number of documents in the corpus
    num_documents = len(lines)

    # Iterate through each document
    for i, line in enumerate(lines):

        # Extract the terms from the document
        terms = line['Tweet Text']

        term_count = defaultdict(int)

        for term in terms:
            term_count[term] += 1

        # Normalize term frequencies in the document
        norm = math.sqrt(sum(count ** 2 for count in term_count.values()))

        for term, count in term_count.items():
            tf_value = np.round(count / norm, 4)  # Calculate TF value for the term
            tf[term].append(tf_value)
            df[term] += 1

    # Calculate IDF for each term
    for term in df:
        idf[term] = np.round(np.log(float(num_documents / df[term])),4)

    return index, tf, df, idf

# %%
# Example usage:
start_time = time.time()
total_index, tf, df, idf = create_index_tfidf(tweet_dicts)
print("Total time to create the index: {} seconds" .format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 0.5 seconds

# %%
total_index
# Out:
# defaultdict(list,
#             {'melsimmonsfcdo': [0],
#              'wrong': [0,
#               24,
#               255,
#               326,
#               444,
#               1321,
#               1497,
#               1511,
#               1595,
#               2092,
#               2156,
#               2206,
#               2235,
#               2236,
#               3713,
#               3843,
#               3899,
#               3946,
#               3993],
#              'dictat': [0, 198, 224, 239, 665, 1861, 2673, 2962, 3114],
#              "putin'": [0,
#               55,
#               98,
#               130,
#               132,
#               135,
#               182,
#               190,
#               245,
#               304,
#               332,
#               414,
#               515,
#               540,
#               576,
#               601,
#               626,
#               676,
#               741,
#               766,
#               809,
#               1185,
#               1388,
#               1477,
#               1571,
#               1693,
#               1696,
#               1702,
#               1736,
#               1738,
#               1867,
#               1885,
#               1886,
#               1899,
#               1966,
#               1994,
#               2007,
#               2098,
#               2108,
#               2178,
#               2469,
#               2594,
#               2596,
#               2636,
#               2639,
#               2682,
#               2719,
#               2723,
#               2755,
#               2937,
#               2989,
#               3081,
#               3088,
#               3111,
#               3185,
#               3239,
#               3416,
#               3430,
#               3435,
#               3564,
#               3566,
#               3878,
#               3957],
#              'fascist': [0, 135, 229, 239, 412, 436, 2402, 2953, 3852],
#              'russia': [0,
#               3,
#               6,
#               8,
#               10,
#               19,
#               30,
#               46,
#               47,
#               62,
#               63,
#               80,
#               86,
#               87,
#               96,
#               110,
#               129,
#               135,
#               140,
#               143,
#               147,
#               152,
#               155,
#               163,
#               194,
#               197,
#               199,
#               203,
#               209,
#               211,
#               220,
#               232,
#               238,
#               247,
#               272,
#               290,
#               294,
#               298,
#               308,
#               314,
#               321,
#               339,
#               340,
#               342,
#               352,
#               372,
#               379,
#               381,
#               384,
#               385,
#               391,
#               392,
#               394,
#               402,
#               406,
#               413,
#               415,
#               416,
#               435,
#               469,
#               472,
#               481,
#               484,
#               490,
#               498,
#               504,
#               506,
#               520,
#               523,
#               533,
#               542,
#               553,
#               554,
#               557,
#               559,
#               560,
#               566,
#               567,
#               574,
#               575,
#               586,
#               588,
#               600,
#               611,
#               614,
#               618,
#               623,
#               631,
#               632,
#               633,
#               640,
#               642,
#               649,
#               660,
#               667,
#               670,
#               681,
#               707,
#               710,
#               712,
#               719,
#               727,
#               751,
#               759,
#               760,
#               761,
#               762,
#               765,
#               776,
#               783,
#               801,
#               806,
#               808,
#               809,
#               812,
#               822,
#               844,
#               850,
#               867,
#               868,
#               882,
#               903,
#               910,
#               937,
#               947,
#               955,
#               959,
#               961,
#               984,
#               986,
#               1002,
#               1008,
#               1014,
#               1015,
#               1027,
#               1041,
#               1048,
#               1049,
#               1057,
#               1060,
#               1064,
#               1070,
#               1091,
#               1098,
#               1099,
#               1126,
#               1139,
#               1179,
#               1196,
#               1202,
#               1212,
#               1213,
#               1221,
#               1222,
#               1240,
#               1251,
#               1261,
#               1275,
#               1287,
#               1294,
#               1299,
#               1310,
#               1318,
#               1321,
#               1336,
#               1342,
#               1347,
#               1349,
#               1357,
#               1362,
#               1374,
#               1396,
#               1413,
#               1418,
#               1461,
#               1463,
#               1476,
#               1487,
#               1493,
#               1504,
#               1527,
#               1528,
#               1532,
#               1534,
#               1536,
#               1538,
#               1545,
#               1546,
#               1569,
#               1573,
#               1576,
#               1587,
#               1593,
#               1598,
#               1600,
#               1603,
#               1605,
#               1606,
#               1616,
#               1619,
#               1626,
#               1628,
#               1633,
#               1642,
#               1643,
#               1645,
#               1648,
#               1660,
#               1665,
#               1666,
#               1669,
#               1674,
#               1678,
#               1679,
#               1684,
#               1688,
#               1691,
#               1706,
#               1708,
#               1709,
#               1719,
#               1720,
#               1728,
#               1731,
#               1732,
#               1733,
#               1735,
#               1747,
#               1751,
#               1760,
#               1770,
#               1782,
#               1799,
#               1812,
#               1831,
#               1838,
#               1839,
#               1847,
#               1851,
#               1864,
#               1866,
#               1875,
#               1879,
#               1883,
#               1889,
#               1896,
#               1902,
#               1903,
#               1907,
#               1919,
#               1926,
#               1929,
#               1937,
#               1952,
#               2047,
#               2049,
#               2051,
#               2062,
#               2079,
#               2082,
#               2085,
#               2093,
#               2100,
#               2102,
#               2103,
#               2107,
#               2110,
#               2112,
#               2114,
#               2125,
#               2130,
#               2140,
#               2153,
#               2189,
#               2204,
#               2212,
#               2237,
#               2251,
#               2258,
#               2259,
#               2262,
#               2264,
#               2265,
#               2273,
#               2280,
#               2283,
#               2291,
#               2292,
#               2310,
#               2317,
#               2333,
#               2338,
#               2357,
#               2368,
#               2369,
#               2372,
#               2376,
#               2383,
#               2403,
#               2408,
#               2409,
#               2410,
#               2411,
#               2415,
#               2416,
#               2431,
#               2447,
#               2450,
#               2462,
#               2466,
#               2494,
#               2495,
#               2499,
#               2500,
#               2501,
#               2502,
#               2505,
#               2506,
#               2508,
#               2510,
#               2511,
#               2512,
#               2513,
#               2514,
#               2515,
#               2516,
#               2518,
#               2519,
#               2520,
#               2521,
#               2522,
#               2523,
#               2524,
#               2527,
#               2529,
#               2532,
#               2537,
#               2538,
#               2539,
#               2544,
#               2562,
#               2566,
#               2574,
#               2575,
#               2584,
#               2587,
#               2588,
#               2589,
#               2590,
#               2593,
#               2607,
#               2620,
#               2633,
#               2643,
#               2653,
#               2660,
#               2661,
#               2672,
#               2676,
#               2705,
#               2712,
#               2714,
#               2720,
#               2721,
#               2739,
#               2740,
#               2766,
#               2770,
#               2787,
#               2788,
#               2789,
#               2792,
#               2802,
#               2805,
#               2806,
#               2810,
#               2827,
#               2849,
#               2891,
#               2908,
#               2913,
#               2925,
#               2936,
#               2937,
#               2946,
#               2950,
#               2963,
#               2971,
#               2982,
#               2983,
#               2987,
#               2995,
#               3011,
#               3012,
#               3014,
#               3020,
#               3038,
#               3061,
#               3062,
#               3071,
#               3088,
#               3096,
#               3121,
#               3129,
#               3131,
#               3134,
#               3176,
#               3189,
#               3203,
#               3209,
#               3212,
#               3216,
#               3227,
#               3242,
#               3249,
#               3250,
#               3257,
#               3265,
#               3270,
#               3322,
#               3330,
#               3354,
#               3360,
#               3368,
#               3372,
#               3377,
#               3378,
#               3402,
#               3411,
#               3421,
#               3447,
#               3469,
#               3470,
#               3478,
#               3487,
#               3491,
#               3506,
#               3528,
#               3534,
#               3541,
#               3542,
#               3544,
#               3546,
#               3554,
#               3557,
#               3558,
#               3559,
#               3563,
#               3588,
#               3593,
#               3602,
#               3607,
#               3617,
#               3620,
#               3636,
#               3638,
#               3648,
#               3668,
#               3681,
#               3692,
#               3706,
#               3718,
#               3720,
#               3725,
#               3730,
#               3740,
#               3750,
#               3753,
#               3761,
#               3763,
#               3789,
#               3794,
#               3797,
#               3809,
#               3811,
#               3837,
#               3853,
#               3861,
#               3863,
#               3866,
#               3868,
#               3870,
#               3871,
#               3877,
#               3891,
#               3910,
#               3918,
#               3921,
#               3927,
#               3928,
#               3930,
#               3935,
#               3938,
#               3939,
#               3961,
#               3968,
#               3969,
#               3976,
#               3983,
#               3985,
#               3995,
#               3997],
#              'intend': [0, 226, 1883, 2612, 3728],
#              'conquer': [0, 381],
#              'much': [0,
#               22,
#               79,
#               444,
#               497,
#               657,
#               858,
#               859,
#               908,
#               1321,
#               1414,
#               1883,
#               1929,
#               2136,
#               3006,
#               3050,
#               3157,
#               3253,
#               3325,
#               3404,
#               3406,
#               3490,
#               3710,
#               3805,
#               3945,
#               3949,
#               3980,
#               3999],
#              'ukrainian': [0,
#               7,
#               16,
#               20,
#               27,
#               30,
#               31,
#               48,
#               49,
#               62,
#               72,
#               103,
#               110,
#               111,
#               112,
#               121,
#               134,
#               152,
#               154,
#               155,
#               159,
#               164,
#               169,
#               170,
#               174,
#               184,
#               196,
#               197,
#               205,
#               209,
#               212,
#               216,
#               221,
#               222,
#               232,
#               239,
#               247,
#               318,
#               319,
#               333,
#               335,
#               365,
#               367,
#               371,
#               375,
#               377,
#               386,
#               393,
#               398,
#               406,
#               410,
#               413,
#               423,
#               424,
#               436,
#               448,
#               452,
#               466,
#               493,
#               502,
#               507,
#               516,
#               520,
#               521,
#               529,
#               530,
#               531,
#               544,
#               559,
#               562,
#               570,
#               580,
#               591,
#               616,
#               621,
#               632,
#               633,
#               643,
#               670,
#               677,
#               681,
#               718,
#               726,
#               737,
#               764,
#               767,
#               769,
#               772,
#               784,
#               808,
#               847,
#               854,
#               860,
#               864,
#               875,
#               877,
#               878,
#               880,
#               884,
#               887,
#               898,
#               911,
#               916,
#               959,
#               968,
#               978,
#               993,
#               1010,
#               1013,
#               1025,
#               1033,
#               1049,
#               1078,
#               1079,
#               1081,
#               1095,
#               1132,
#               1141,
#               1146,
#               1175,
#               1182,
#               1187,
#               1196,
#               1197,
#               1204,
#               1223,
#               1228,
#               1234,
#               1244,
#               1250,
#               1252,
#               1253,
#               1256,
#               1257,
#               1258,
#               1269,
#               1272,
#               1276,
#               1286,
#               1289,
#               1290,
#               1308,
#               1315,
#               1334,
#               1367,
#               1382,
#               1392,
#               1398,
#               1422,
#               1449,
#               1453,
#               1461,
#               1465,
#               1470,
#               1482,
#               1488,
#               1490,
#               1511,
#               1533,
#               1538,
#               1551,
#               1552,
#               1559,
#               1560,
#               1567,
#               1583,
#               1589,
#               1590,
#               1601,
#               1646,
#               1674,
#               1675,
#               1676,
#               1681,
#               1692,
#               1694,
#               1698,
#               1734,
#               1737,
#               1739,
#               1740,
#               1744,
#               1747,
#               1832,
#               1856,
#               1864,
#               1871,
#               1892,
#               1901,
#               1911,
#               1927,
#               1953,
#               1954,
#               1958,
#               1969,
#               1972,
#               1974,
#               1976,
#               2005,
#               2019,
#               2021,
#               2024,
#               2037,
#               2039,
#               2050,
#               2057,
#               2060,
#               2068,
#               2083,
#               2084,
#               2086,
#               2098,
#               2117,
#               2118,
#               2121,
#               2130,
#               2133,
#               2134,
#               2135,
#               2141,
#               2162,
#               2163,
#               2170,
#               2175,
#               2188,
#               2195,
#               2196,
#               2197,
#               2214,
#               2225,
#               2227,
#               2228,
#               2231,
#               2233,
#               2252,
#               2258,
#               2263,
#               2268,
#               2272,
#               2279,
#               2281,
#               2298,
#               2304,
#               2339,
#               2341,
#               2342,
#               2366,
#               2370,
#               2375,
#               2378,
#               2380,
#               2381,
#               2384,
#               2387,
#               2390,
#               2395,
#               2399,
#               2405,
#               2426,
#               2428,
#               2434,
#               2436,
#               2437,
#               2441,
#               2448,
#               2453,
#               2459,
#               2465,
#               2466,
#               2467,
#               2478,
#               2482,
#               2529,
#               2532,
#               2549,
#               2554,
#               2561,
#               2562,
#               2563,
#               2564,
#               2577,
#               2579,
#               2591,
#               2595,
#               2597,
#               2600,
#               2602,
#               2603,
#               2605,
#               2606,
#               2608,
#               2628,
#               2630,
#               2635,
#               2638,
#               2649,
#               2650,
#               2655,
#               2674,
#               2679,
#               2681,
#               2683,
#               2687,
#               2698,
#               2708,
#               2709,
#               2711,
#               2713,
#               2715,
#               2718,
#               2721,
#               2724,
#               2732,
#               2734,
#               2743,
#               2757,
#               2776,
#               2794,
#               2795,
#               2813,
#               2821,
#               2823,
#               2824,
#               2828,
#               2830,
#               2834,
#               2835,
#               2840,
#               2848,
#               2856,
#               2857,
#               2889,
#               2902,
#               2905,
#               2921,
#               2930,
#               2931,
#               2934,
#               2935,
#               2937,
#               2939,
#               2955,
#               2993,
#               2996,
#               2998,
#               3013,
#               3037,
#               3038,
#               3044,
#               3047,
#               3055,
#               3057,
#               3059,
#               3073,
#               3075,
#               3094,
#               3120,
#               3127,
#               3132,
#               3135,
#               3194,
#               3213,
#               3227,
#               3233,
#               3242,
#               3250,
#               3263,
#               3266,
#               3267,
#               3284,
#               3285,
#               3294,
#               3312,
#               3313,
#               3314,
#               3347,
#               3367,
#               3374,
#               3386,
#               3393,
#               3399,
#               3412,
#               3418,
#               3426,
#               3433,
#               3452,
#               3471,
#               3473,
#               3474,
#               3475,
#               3504,
#               3528,
#               3533,
#               3536,
#               3552,
#               3560,
#               3561,
#               3565,
#               3567,
#               3572,
#               3611,
#               3619,
#               3645,
#               3652,
#               3654,
#               3662,
#               3669,
#               3687,
#               3700,
#               3701,
#               3706,
#               3708,
#               3718,
#               3721,
#               3735,
#               3751,
#               3765,
#               3767,
#               3768,
#               3776,
#               3798,
#               3801,
#               3804,
#               3844,
#               3884,
#               3913,
#               3921,
#               3924,
#               3931,
#               3946,
#               3947,
#               3948,
#               3962,
#               3970,
#               3995],
#              'land': [0,
#               21,
#               72,
#               172,
#               180,
#               196,
#               211,
#               316,
#               567,
#               586,
#               600,
#               618,
#               639,
#               652,
#               660,
#               676,
#               1106,
#               1110,
#               1112,
#               1116,
#               1121,
#               1122,
#               1124,
#               1125,
#               1127,
#               1135,
#               1138,
#               1153,
#               1159,
#               1163,
#               1179,
#               1197,
#               1280,
#               1316,
#               1414,
#               1438,
#               1702,
#               1878,
#               1911,
#               2075,
#               2108,
#               2110,
#               2239,
#               2242,
#               2384,
#               2389,
#               2467,
#               2608,
#               2692,
#               2713,
#               2803,
#               2865,
#               2911,
#               3082,
#               3142,
#               3207,
#               3270,
#               3294,
#               3383,
#               3671,
#               3727,
#               3921,
#               3972],
#              'possibl': [0,
#               5,
#               79,
#               104,
#               123,
#               248,
#               427,
#               466,
#               659,
#               975,
#               1217,
#               1262,
#               1428,
#               1618,
#               1806,
#               1858,
#               2026,
#               2234,
#               2280,
#               2611,
#               2714,
#               2726,
#               2868,
#               2891,
#               2894,
#               2895,
#               2982,
#               3076,
#               3152,
#               3280,
#               3527,
#               3629,
#               3692,
#               3771,
#               3959,
#               3997],
#              'arm': [1,
#               36,
#               108,
#               206,
#               215,
#               230,
#               284,
#               334,
#               355,
#               505,
#               520,
#               541,
#               560,
#               594,
#               616,
#               621,
#               628,
#               668,
#               722,
#               805,
#               826,
#               827,
#               887,
#               912,
#               932,
#               975,
#               1066,
#               1068,
#               1075,
#               1171,
#               1201,
#               1203,
#               1211,
#               1230,
#               1237,
#               1306,
#               1442,
#               1452,
#               1453,
#               1465,
#               1482,
#               1483,
#               1490,
#               1650,
#               1657,
#               1740,
#               1787,
#               1794,
#               1810,
#               1814,
#               1870,
#               1880,
#               2003,
#               2014,
#               2039,
#               2044,
#               2094,
#               2095,
#               2105,
#               2139,
#               2277,
#               2323,
#               2328,
#               2363,
#               2387,
#               2458,
#               2467,
#               2470,
#               2577,
#               2600,
#               2605,
#               2606,
#               2696,
#               2707,
#               2708,
#               2718,
#               2730,
#               2905,
#               2965,
#               2977,
#               2996,
#               3012,
#               3316,
#               3381,
#               3386,
#               3408,
#               3414,
#               3442,
#               3457,
#               3458,
#               3462,
#               3491,
#               3499,
#               3576,
#               3577,
#               3593,
#               3611,
#               3625,
#               3642,
#               3651,
#               3655,
#               3738,
#               3770,
#               3920,
#               3931],
#              'forc': [1,
#               7,
#               36,
#               38,
#               59,
#               72,
#               76,
#               79,
#               87,
#               90,
#               108,
#               169,
#               177,
#               205,
#               206,
#               222,
#               230,
#               259,
#               261,
#               278,
#               284,
#               319,
#               334,
#               355,
#               356,
#               398,
#               448,
#               505,
#               520,
#               527,
#               529,
#               541,
#               550,
#               558,
#               559,
#               564,
#               591,
#               594,
#               616,
#               619,
#               621,
#               637,
#               674,
#               691,
#               701,
#               734,
#               767,
#               771,
#               781,
#               805,
#               827,
#               845,
#               855,
#               876,
#               887,
#               912,
#               921,
#               926,
#               932,
#               941,
#               944,
#               948,
#               960,
#               975,
#               1003,
#               1023,
#               1031,
#               1053,
#               1066,
#               1068,
#               1075,
#               1090,
#               1130,
#               1171,
#               1177,
#               1181,
#               1187,
#               1197,
#               1199,
#               1201,
#               1203,
#               1211,
#               1216,
#               1219,
#               1230,
#               1232,
#               1237,
#               1244,
#               1260,
#               1280,
#               1284,
#               1306,
#               1315,
#               1355,
#               1367,
#               1373,
#               1377,
#               1392,
#               1399,
#               1408,
#               1440,
#               1442,
#               1452,
#               1453,
#               1456,
#               1465,
#               1476,
#               1481,
#               1482,
#               1490,
#               1498,
#               1532,
#               1552,
#               1646,
#               1657,
#               1699,
#               1737,
#               1740,
#               1742,
#               1755,
#               1794,
#               1814,
#               1856,
#               1870,
#               1880,
#               1963,
#               1969,
#               1976,
#               2003,
#               2014,
#               2043,
#               2044,
#               2050,
#               2084,
#               2094,
#               2095,
#               2103,
#               2166,
#               2173,
#               2174,
#               2195,
#               2202,
#               2208,
#               2252,
#               2258,
#               2268,
#               2276,
#               2277,
#               2281,
#               2304,
#               2323,
#               2342,
#               2363,
#               2378,
#               2381,
#               2387,
#               2424,
#               2459,
#               2466,
#               2467,
#               2497,
#               2548,
#               2564,
#               2577,
#               2595,
#               2599,
#               2600,
#               2605,
#               2606,
#               2628,
#               2657,
#               2690,
#               2691,
#               2707,
#               2708,
#               2718,
#               2731,
#               2734,
#               2738,
#               2755,
#               2795,
#               2796,
#               2814,
#               2820,
#               2823,
#               2836,
#               2839,
#               2846,
#               2856,
#               2905,
#               2937,
#               2965,
#               2973,
#               2977,
#               2978,
#               2996,
#               3005,
#               3022,
#               3040,
#               3199,
#               3204,
#               3240,
#               3267,
#               3316,
#               3370,
#               3381,
#               3386,
#               3402,
#               3408,
#               3410,
#               3412,
#               3414,
#               3418,
#               3442,
#               3457,
#               3458,
#               3459,
#               3462,
#               3471,
#               3499,
#               3505,
#               3507,
#               3528,
#               3565,
#               3570,
#               3576,
#               3577,
#               3579,
#               3580,
#               3588,
#               3593,
#               3610,
#               3611,
#               3625,
#               3642,
#               3669,
#               3687,
#               3738,
#               3751,
#               3762,
#               3770,
#               3776,
#               3785,
#               3802,
#               3806,
#               3811,
#               3855,
#               3895,
#               3914,
#               3920,
#               3931,
#               3963,
#               3966,
#               3970,
#               3971,
#               3998],
#              'liber': [1,
#               36,
#               74,
#               90,
#               118,
#               186,
#               205,
#               241,
#               448,
#               520,
#               677,
#               772,
#               836,
#               1066,
#               1147,
#               1219,
#               1244,
#               1290,
#               1572,
#               1744,
#               1909,
#               1929,
#               1976,
#               2141,
#               2387,
#               2424,
#               2435,
#               2467,
#               2478,
#               2577,
#               2600,
#               2602,
#               2718,
#               2865,
#               2875,
#               2947,
#               3183,
#               3242,
#               3435,
#               3572,
#               3785,
#               3904,
#               3931,
#               3970],
#              'villag': [1,
#               36,
#               798,
#               905,
#               1074,
#               1206,
#               1306,
#               2424,
#               2435,
#               2687,
#               2698,
#               3022,
#               3466,
#               3526],
#              'urban': [1, 1257],
#              'territori': [1,
#               3,
#               7,
#               15,
#               25,
#               26,
#               27,
#               30,
#               31,
#               40,
#               62,
#               93,
#               152,
#               159,
#               188,
#               199,
#               211,
#               232,
#               280,
#               297,
#               321,
#               354,
#               377,
#               381,
#               382,
#               387,
#               390,
#               396,
#               410,
#               413,
#               455,
#               468,
#               469,
#               472,
#               481,
#               484,
#               519,
#               520,
#               562,
#               566,
#               579,
#               580,
#               632,
#               643,
#               682,
#               694,
#               711,
#               814,
#               822,
#               836,
#               867,
#               881,
#               903,
#               940,
#               942,
#               989,
#               1095,
#               1147,
#               1197,
#               1209,
#               1227,
#               1257,
#               1322,
#               1353,
#               1425,
#               1470,
#               1472,
#               1488,
#               1501,
#               1533,
#               1592,
#               1617,
#               1633,
#               1681,
#               1690,
#               1691,
#               1698,
#               1730,
#               1740,
#               1748,
#               1769,
#               1804,
#               1883,
#               1892,
#               1909,
#               1945,
#               1958,
#               1960,
#               1971,
#               2047,
#               2051,
#               2073,
#               2080,
#               2189,
#               2196,
#               2208,
#               2255,
#               2258,
#               2279,
#               2282,
#               2298,
#               2341,
#               2348,
#               2370,
#               2382,
#               2387,
#               2445,
#               2449,
#               2469,
#               2478,
#               2499,
#               2500,
#               2501,
#               2502,
#               2505,
#               2506,
#               2508,
#               2510,
#               2511,
#               2512,
#               2513,
#               2514,
#               2515,
#               2516,
#               2518,
#               2519,
#               2520,
#               2521,
#               2522,
#               2523,
#               2524,
#               2532,
#               2557,
#               2563,
#               2577,
#               2586,
#               2624,
#               2656,
#               2715,
#               2718,
#               2723,
#               2728,
#               2729,
#               2803,
#               2805,
#               3024,
#               3040,
#               3150,
#               3242,
#               3360,
#               3435,
#               3441,
#               3509,
#               3528,
#               3556,
#               3602,
#               3623,
#               3696,
#               3728,
#               3811,
#               3872,
#               3891,
#               3962,
#               3995,
#               3998],
#              'commun': [1,
#               427,
#               468,
#               852,
#               958,
#               978,
#               1116,
#               1137,
#               1185,
#               1257,
#               1847,
#               1877,
#               2206,
#               2754,
#               2908,
#               2987,
#               3053,
#               3451],
#              'regionukrainerussiawar': [1],
#              'alert': [2,
#               61,
#               1277,
#               1286,
#               1336,
#               1636,
#               1903,
#               1950,
#               3146,
#               3297,
#               3328],
#              'poland': [2,
#               139,
#               1015,
#               1556,
#               1830,
#               1846,
#               1879,
#               1920,
#               2089,
#               2209,
#               2265,
#               2488,
#               2754,
#               2853,
#               3664,
#               3668,
#               3935],
#              'prep': [2],
#              'antiradi': [2],
#              'tablet': [2],
#              'nuclear': [2,
#               17,
#               68,
#               73,
#               94,
#               115,
#               128,
#               152,
#               179,
#               283,
#               290,
#               295,
#               297,
#               331,
#               511,
#               524,
#               535,
#               536,
#               606,
#               612,
#               646,
#               861,
#               872,
#               1102,
#               1104,
#               1130,
#               1137,
#               1191,
#               1246,
#               1250,
#               1252,
#               1253,
#               1299,
#               1336,
#               1356,
#               1419,
#               1426,
#               1463,
#               1511,
#               1648,
#               1660,
#               1668,
#               1679,
#               1683,
#               1740,
#               1763,
#               1824,
#               1847,
#               1848,
#               1903,
#               2011,
#               2026,
#               2048,
#               2055,
#               2112,
#               2145,
#               2155,
#               2182,
#               2280,
#               2357,
#               2368,
#               2404,
#               2460,
#               2503,
#               2553,
#               2566,
#               2615,
#               2695,
#               2705,
#               2724,
#               2739,
#               2743,
#               2803,
#               2868,
#               2929,
#               2959,
#               2987,
#               3061,
#               3122,
#               3128,
#               3141,
#               3268,
#               3315,
#               3347,
#               3361,
#               3367,
#               3391,
#               3491,
#               3574,
#               3665,
#               3692,
#               3695,
#               3755,
#               3865,
#               3905,
#               3928,
#               3932,
#               3935,
#               3985],
#              'threat': [2,
#               12,
#               67,
#               141,
#               187,
#               308,
#               535,
#               1099,
#               1504,
#               1511,
#               1633,
#               1648,
#               1787,
#               1804,
#               1945,
#               2101,
#               2145,
#               2155,
#               2182,
#               2208,
#               2230,
#               2357,
#               2368,
#               2460,
#               2615,
#               2726,
#               2929,
#               2959,
#               3209,
#               3315,
#               3361,
#               3435,
#               3486,
#               3614,
#               3640,
#               3691,
#               3695,
#               3769,
#               3895],
#              'im': [3,
#               1212,
#               1458,
#               1815,
#               1830,
#               3003,
#               3023,
#               3055,
#               3491,
#               3629,
#               3668,
#               3813,
#               3818,
#               3874],
#              'still': [3,
#               79,
#               243,
#               255,
#               457,
#               540,
#               720,
#               937,
#               978,
#               1019,
#               1029,
#               1034,
#               1299,
#               1334,
#               1414,
#               1434,
#               1496,
#               1538,
#               1755,
#               1939,
#               2085,
#               2128,
#               2327,
#               2557,
#               2656,
#               2665,
#               2724,
#               2743,
#               2959,
#               3244,
#               3347,
#               3367,
#               3506,
#               3843,
#               3870],
#              'wait': [3,
#               679,
#               747,
#               818,
#               928,
#               1048,
#               1113,
#               1151,
#               1768,
#               1946,
#               2462,
#               2481,
#               2866,
#               2960,
#               3226,
#               3305,
#               3734,
#               3870,
#               3906],
#              'googl': [3, 3531],
#              'map': [3,
#               61,
#               315,
#               441,
#               470,
#               515,
#               561,
#               577,
#               887,
#               935,
#               1374,
#               1383,
#               1391,
#               1426,
#               1629,
#               1844,
#               1953,
#               2070,
#               2301,
#               2444,
#               2461,
#               2482,
#               2791,
#               2844,
#               2961,
#               3605],
#              'updat': [3,
#               167,
#               250,
#               315,
#               461,
#               470,
#               479,
#               565,
#               654,
#               692,
#               731,
#               753,
#               789,
#               839,
#               880,
#               935,
#               1157,
#               1222,
#               1366,
#               1472,
#               1562,
#               1831,
#               1846,
#               1961,
#               2097,
#               2213,
#               2451,
#               2533,
#               2604,
#               2694,
#               2764,
#               2943,
#               2963,
#               3062,
#               3163,
#               3306,
#               3313,
#               3356,
#               3533],
#              'new': [3,
#               45,
#               46,
#               82,
#               83,
#               88,
#               116,
#               127,
#               132,
#               155,
#               181,
#               188,
#               240,
#               254,
#               312,
#               361,
#               371,
#               391,
#               404,
#               412,
#               424,
#               428,
#               431,
#               436,
#               481,
#               492,
#               511,
#               525,
#               554,
#               564,
#               566,
#               568,
#               579,
#               683,
#               694,
#               707,
#               712,
#               719,
#               727,
#               790,
#               794,
#               838,
#               875,
#               945,
#               997,
#               1002,
#               1058,
#               1123,
#               1147,
#               1175,
#               1193,
#               1202,
#               1226,
#               1241,
#               1248,
#               1297,
#               1299,
#               1318,
#               1362,
#               1405,
#               1410,
#               1415,
#               1438,
#               1542,
#               1543,
#               1648,
#               1875,
#               1948,
#               2047,
#               2078,
#               2101,
#               2105,
#               2106,
#               2115,
#               2119,
#               2140,
#               2169,
#               2210,
#               2214,
#               2255,
#               2322,
#               2328,
#               2333,
#               2382,
#               2479,
#               2483,
#               2495,
#               2496,
#               2537,
#               2631,
#               2714,
#               2728,
#               2740,
#               2914,
#               2928,
#               2944,
#               2959,
#               2972,
#               2973,
#               2978,
#               2991,
#               3024,
#               3053,
#               3064,
#               3086,
#               3096,
#               3103,
#               3124,
#               3165,
#               3181,
#               3234,
#               3257,
#               3272,
#               3276,
#               3300,
#               3345,
#               3346,
#               3382,
#               3396,
#               3415,
#               3435,
#               3461,
#               3479,
#               3487,
#               3495,
#               3582,
#               3590,
#               3593,
#               3604,
#               3607,
#               3608,
#               3609,
#               3645,
#               3651,
#               3655,
#               3729,
#               3795,
#               3806,
#               3824,
#               3846,
#               3858,
#               3867,
#               3871,
#               3912,
#               3919,
#               3935,
#               3939,
#               3945,
#               3966],
#              'annex': [3,
#               7,
#               15,
#               21,
#               27,
#               30,
#               31,
#               40,
#               49,
#               62,
#               64,
#               86,
#               87,
#               88,
#               101,
#               105,
#               112,
#               117,
#               118,
#               130,
#               136,
#               155,
#               159,
#               163,
#               169,
#               176,
#               178,
#               180,
#               182,
#               185,
#               188,
#               194,
#               209,
#               227,
#               232,
#               246,
#               247,
#               260,
#               265,
#               286,
#               304,
#               316,
#               321,
#               361,
#               364,
#               371,
#               372,
#               374,
#               377,
#               382,
#               384,
#               386,
#               409,
#               410,
#               413,
#               417,
#               428,
#               435,
#               462,
#               464,
#               468,
#               469,
#               484,
#               487,
#               489,
#               516,
#               519,
#               521,
#               530,
#               554,
#               562,
#               566,
#               567,
#               574,
#               578,
#               579,
#               580,
#               584,
#               590,
#               596,
#               603,
#               618,
#               632,
#               643,
#               647,
#               661,
#               667,
#               670,
#               694,
#               703,
#               710,
#               711,
#               714,
#               724,
#               783,
#               790,
#               795,
#               801,
#               807,
#               808,
#               812,
#               818,
#               822,
#               836,
#               857,
#               867,
#               903,
#               920,
#               925,
#               933,
#               944,
#               949,
#               984,
#               1004,
#               1039,
#               1092,
#               1095,
#               1180,
#               1195,
#               1197,
#               1209,
#               1374,
#               1463,
#               1488,
#               1489,
#               1494,
#               1496,
#               1499,
#               1505,
#               1533,
#               1538,
#               1555,
#               1587,
#               1617,
#               1628,
#               1647,
#               1681,
#               1696,
#               1698,
#               1702,
#               1753,
#               1757,
#               1776,
#               1804,
#               1812,
#               1864,
#               1891,
#               1898,
#               1909,
#               1934,
#               1949,
#               2051,
#               2062,
#               2072,
#               2075,
#               2085,
#               2092,
#               2098,
#               2108,
#               2125,
#               2151,
#               2196,
#               2208,
#               2239,
#               2242,
#               2247,
#               2279,
#               2298,
#               2317,
#               2341,
#               2370,
#               2372,
#               2375,
#               2403,
#               2469,
#               2529,
#               2532,
#               2624,
#               2633,
#               2636,
#               2640,
#               2656,
#               2667,
#               2713,
#               2715,
#               2719,
#               2720,
#               2723,
#               2787,
#               2789,
#               2792,
#               2803,
#               3024,
#               3206,
#               3227,
#               3360,
#               3441,
#               3470,
#               3537,
#               3607,
#               3634,
#               3671,
#               3690,
#               3696,
#               3697,
#               3724,
#               3728,
#               3811,
#               3872,
#               3891,
# ...
#               3459,
#               3508,
#               3672,
#               3807,
#               3885,
#               3900,
#               3902,
#               3903],
#              'clash': [144],
#              'u': [145, 1374, 2157, 2206, 2617, 2951, 3336, 3717],
#              'rat': [145, 607, 1046, 2621, 2704],
#              'rape': [145, 2157, 3717],
#              'begir': [145],
#              'summer': [145, 1487, 2754],
#              '23': [145,
#               194,
#               406,
#               882,
#               907,
#               920,
#               970,
#               1024,
#               1039,
#               1064,
#               1173,
#               1180,
#               1238,
#               1289,
#               1298,
#               1305,
#               1307,
#               1315,
#               1319,
#               1324,
#               1328,
#               1351,
#               1359,
#               1385,
#               1387,
#               1883],
#              'manhattan': [146],
#              'ride': [146],
#              'freedom': [148, 166, 343, 402, 1155, 1292, 2799, 3476],
#              'financi': [149, 163, 928, 1268, 1596, 1855],
#              'caus': [149,
#               187,
#               444,
#               842,
#               1010,
#               1457,
#               1529,
#               1631,
#               1706,
#               1869,
#               1967,
#               2403,
#               2466,
#               2695,
#               2907,
#               3278,
#               3440,
#               3624,
#               3647,
#               3854,
#               3892],
#              'pocket': [149, 550, 916, 2019, 2142, 3732],
#              'saw': [149, 3468, 3668, 3692],
#              'caribean': [149],
#              'tax': [149, 197, 202, 299, 800],
#              'heaven': [149, 1101],
#              'secret': [149, 1201, 1203, 1242, 1666, 2034, 2861, 3549, 3793],
#              'account': [149, 2168, 2434, 2474, 2557, 3145, 3182, 3495, 3854],
#              'expos': [149, 201, 2216, 2970, 3819],
#              'pandora': [149, 1718],
#              'paper': [149,
#               377,
#               386,
#               596,
#               603,
#               1718,
#               2401,
#               2838,
#               3131,
#               3793,
#               3809],
#              'ampnato': [149],
#              'sold': [149, 3492, 3569],
#              '3rd': [149, 3863],
#              'countriesukrain': [149],
#              'guard': [150,
#               539,
#               668,
#               975,
#               1193,
#               1483,
#               1581,
#               2056,
#               2225,
#               2309,
#               2497,
#               2562,
#               2657,
#               2840,
#               2885,
#               3925],
#              'spot': [150, 365, 954, 2697, 2802],
#              'two': [150,
#               365,
#               523,
#               546,
#               638,
#               756,
#               862,
#               1067,
#               1092,
#               1241,
#               1375,
#               1381,
#               1398,
#               1446,
#               1448,
#               1472,
#               1548,
#               1694,
#               1695,
#               1724,
#               1828,
#               1869,
#               1954,
#               1969,
#               2052,
#               2215,
#               2268,
#               2284,
#               2323,
#               2388,
#               2412,
#               2428,
#               2472,
#               2492,
#               2531,
#               2581,
#               2658,
#               2700,
#               2938,
#               3012,
#               3143,
#               3204,
#               3312,
#               3331,
#               3549,
#               3589,
#               3662,
#               3701,
#               3736,
#               3781,
#               3792,
#               3840],
#              'silhouett': [150],
#              'shape': [150, 3446],
#              'behind': [150,
#               303,
#               833,
#               849,
#               928,
#               1479,
#               1526,
#               1770,
#               1821,
#               1983,
#               2109,
#               2430,
#               2887,
#               3215,
#               3283,
#               3438,
#               3657,
#               3762],
#              'wild': [150, 3874],
#              'boar': [150],
#              'moldova': [150],
#              'young': [150,
#               172,
#               891,
#               1503,
#               1570,
#               2694,
#               3424,
#               3515,
#               3826,
#               3828,
#               3829,
#               3830,
#               3832,
#               3834,
#               3836,
#               3838],
#              'draft': [150,
#               1226,
#               1435,
#               1470,
#               1484,
#               1862,
#               2033,
#               2291,
#               2336,
#               2678,
#               2803,
#               3071,
#               3100,
#               3112,
#               3217,
#               3352,
#               3432,
#               3468,
#               3515,
#               3542,
#               3544,
#               3620,
#               3637,
#               3677,
#               3777,
#               3943],
#              'age': [150,
#               627,
#               1350,
#               2691,
#               2809,
#               2846,
#               3000,
#               3039,
#               3071,
#               3499,
#               3750,
#               3792,
#               3956],
#              'getaway': [150],
#              'deni': [150, 347, 523, 1043, 1694, 1961, 2547, 3464],
#              'blast': [151, 1916, 1995, 2147, 3455, 3957],
#              'outright': [151],
#              'satan': [151, 1660],
#              'secretari': [152,
#               175,
#               211,
#               279,
#               290,
#               296,
#               301,
#               305,
#               310,
#               320,
#               419,
#               559,
#               809,
#               1172,
#               1363,
#               1389,
#               2049,
#               2074,
#               2129,
#               2488,
#               3028,
#               3261,
#               3488,
#               3930],
#              'retak': [152, 1250, 1252, 1253, 3383, 3972],
#              'blackmail': [152, 331, 3461, 3665],
#              'convey': [152, 892, 2825],
#              'ite': [153,
#               383,
#               496,
#               943,
#               1052,
#               1210,
#               1376,
#               1653,
#               1936,
#               3084,
#               3085],
#              'pedicabo': [153,
#               383,
#               496,
#               943,
#               1052,
#               1210,
#               1376,
#               1653,
#               1936,
#               3084,
#               3085],
#              'te': [153,
#               383,
#               496,
#               943,
#               1052,
#               1210,
#               1376,
#               1653,
#               1936,
#               3084,
#               3085],
#              'ipsum': [153,
#               383,
#               496,
#               943,
#               1052,
#               1210,
#               1376,
#               1653,
#               1936,
#               3084,
#               3085],
#              'latin': [153,
#               383,
#               496,
#               943,
#               1052,
#               1210,
#               1376,
#               1653,
#               1936,
#               3084,
#               3085],
#              'friday': [155,
#               176,
#               178,
#               279,
#               426,
#               1172,
#               1363,
#               1655,
#               1698,
#               2081,
#               2196,
#               2298,
#               2372,
#               2375,
#               2383,
#               2432,
#               2436,
#               2529,
#               2607,
#               2636,
#               2715,
#               2720],
#              'sever': [155,
#               302,
#               372,
#               413,
#               428,
#               890,
#               1009,
#               1258,
#               1348,
#               1417,
#               1439,
#               1855,
#               1930,
#               1977,
#               2019,
#               2119,
#               2219,
#               2358,
#               2766,
#               3066,
#               3152,
#               3338,
#               3947],
#              'joe': [155,
#               417,
#               444,
#               1212,
#               1709,
#               2438,
#               2483,
#               2490,
#               3486,
#               3569,
#               3781],
#              "moscow'": [155, 294, 2959],
#              'fraudul': [155, 417],
#              'run': [156,
#               274,
#               376,
#               492,
#               624,
#               893,
#               1247,
#               1338,
#               1474,
#               1481,
#               1703,
#               1759,
#               1829,
#               2083,
#               2134,
#               2899,
#               2934,
#               2994,
#               3002,
#               3031,
#               3162,
#               3280,
#               3406,
#               3517,
#               3575,
#               3779,
#               3809,
#               3874,
#               3947],
#              'beschlossdc': [157],
#              'sitdown': [157],
#              'jordanbpeterson': [157],
#              'media': [157,
#               389,
#               664,
#               677,
#               1065,
#               1082,
#               1172,
#               1186,
#               1270,
#               1330,
#               1355,
#               1455,
#               1665,
#               1704,
#               2249,
#               2252,
#               2256,
#               2308,
#               2363,
#               2391,
#               3101,
#               3120,
#               3151,
#               3206,
#               3217,
#               3221,
#               3354,
#               3406,
#               3824,
#               3861],
#              'celebr': [157,
#               260,
#               474,
#               593,
#               611,
#               795,
#               944,
#               1011,
#               1098,
#               1718,
#               2293,
#               2656],
#              'seek': [157, 671, 3010, 3857, 3880, 3949, 3962],
#              'offer': [157,
#               1084,
#               1086,
#               1088,
#               2945,
#               3022,
#               3088,
#               3368,
#               3794,
#               3990],
#              'excus': [157, 2876],
#              'scum': [158, 700, 1196, 2032],
#              'unequivoc': [159, 270, 574, 634, 2831],
#              'shout': [160, 3799],
#              'gangster': [160],
#              'bulli': [160, 1045, 1504, 1526, 3907],
#              'teenag': [160],
#              'postannex': [160],
#              'neighborhood': [160, 2816],
#              'tragic': [160, 1449, 3825],
#              'whistl': [160],
#              'walk': [160, 1029, 1674, 3916],
#              'cemeteri': [160],
#              'bad': [160, 309, 331, 1184, 1579, 1582, 2043, 2962, 3993],
#              'await': [160, 828],
#              'awar': [160, 3509],
#              'livabl': [161],
#              'stoltenberg': [162, 175, 182, 211, 279, 295, 296, 310, 323, 419],
#              'agenc': [162,
#               210,
#               417,
#               631,
#               654,
#               655,
#               703,
#               740,
#               1216,
#               1385,
#               1655,
#               2455,
#               2720,
#               3604,
#               3917],
#              'coincid': [162, 1441, 3287],
#              'victori': [162,
#               564,
#               1211,
#               1293,
#               1346,
#               1940,
#               2062,
#               2193,
#               2269,
#               2271,
#               2278,
#               2287,
#               2288,
#               2295,
#               2296,
#               2300,
#               2311,
#               2313,
#               2316,
#               2319,
#               2320,
#               2324,
#               2329,
#               2337,
#               2353,
#               2504,
#               2509,
#               2865,
#               2916,
#               2970,
#               3151,
#               3638,
#               3666],
#              'shambol': [163],
#              'tweet': [163,
#               678,
#               1568,
#               1670,
#               1705,
#               2136,
#               2245,
#               2825,
#               3502,
#               3668,
#               3680,
#               3856,
#               3949],
#              '15pc': [163],
#              'noahmurphynft': [164],
#              'promot': [164, 2479, 3370],
#              'nft': [164],
#              'project': [164, 1175, 1758, 2492, 3747],
#              'childen': [164],
#              'women': [164,
#               614,
#               828,
#               1484,
#               1941,
#               2149,
#               2336,
#               2431,
#               2548,
#               2614,
#               2619,
#               2846,
#               2971,
#               3413],
#              'mean': [164,
#               322,
#               394,
#               491,
#               508,
#               517,
#               652,
#               682,
#               694,
#               892,
#               1074,
#               1139,
#               1616,
#               1881,
#               2087,
#               2096,
#               2539,
#               2544,
#               2714,
#               3098,
#               3121,
#               3185,
#               3371,
#               3426,
#               3487,
#               3640,
#               3656,
#               3705,
#               3715,
#               3811,
#               3888,
#               3896,
#               3919],
#              'lot': [164,
#               480,
#               781,
#               949,
#               978,
#               1009,
#               1070,
#               1433,
#               1679,
#               1680,
#               1775,
#               2010,
#               2665,
#               2927,
#               3081,
#               3349,
#               3395,
#               3574,
#               3902,
#               3903,
#               3907,
#               3946,
#               3948,
#               3991],
#              'center': [167,
#               498,
#               542,
#               1029,
#               1314,
#               1420,
#               1704,
#               1828,
#               1932,
#               2549,
#               2646,
#               2666,
#               2843,
#               3101,
#               3131,
#               3399,
#               3673,
#               3738,
#               3885],
#              'sabotag': [167,
#               329,
#               330,
#               422,
#               625,
#               1078,
#               1222,
#               1332,
#               1389,
#               1763,
#               1959,
#               1983,
#               2050,
#               2097,
#               2100,
#               2220,
#               2293,
#               2322,
#               2477,
#               2676,
#               2869,
#               2877,
#               2879,
#               2907,
#               3035,
#               3042,
#               3079,
#               3128,
#               3215,
#               3244,
#               3252,
#               3283,
#               3295,
#               3324,
#               3354,
#               3420,
#               3455,
#               3479,
#               3647,
#               3769,
#               3771,
#               3837,
#               3891],
#              'fear': [167,
#               307,
#               657,
#               1150,
#               1183,
#               1526,
#               1599,
#               1710,
#               2007,
#               2283,
#               2422,
#               2568,
#               3078,
#               3539,
#               3647,
#               3917,
#               3943],
#              'woke': [167, 868],
#              'alex': [167, 2097],
#              'christofor': [167, 2097],
#              'breakingrussia': [169],
#              'partli': [169, 2701],
#              ...})

# %% [markdown]
# Term Frequency measures the frequency of a term (word or phrase) in a specific document.

# %%
tf
# Out:
# defaultdict(list,
#             {'melsimmonsfcdo': [0.2887],
#              'wrong': [0.2887,
#               0.2673,
#               0.8165,
#               0.2357,
#               0.189,
#               0.2294,
#               0.2357,
#               0.3015,
#               0.2357,
#               0.2,
#               0.25,
#               0.2,
#               0.2357,
#               0.2357,
#               0.1925,
#               0.3015,
#               0.2357,
#               0.2236,
#               0.2774],
#              'dictat': [0.2887,
#               0.5,
#               0.5774,
#               0.2357,
#               0.2132,
#               0.2582,
#               0.2425,
#               0.2132,
#               0.5774],
#              "putin'": [0.2887,
#               0.3162,
#               0.3333,
#               0.25,
#               0.3536,
#               0.25,
#               0.1925,
#               0.2236,
#               0.7071,
#               0.3536,
#               0.25,
#               0.2582,
#               0.4472,
#               0.2132,
#               0.4082,
#               0.2236,
#               0.2887,
#               0.25,
#               0.4472,
#               0.3162,
#               0.25,
#               0.2041,
#               0.3162,
#               0.2774,
#               0.3015,
#               0.3015,
#               0.2673,
#               0.1826,
#               0.3162,
#               0.3162,
#               0.3162,
#               0.3162,
#               0.3162,
#               0.3015,
#               0.2582,
#               0.3015,
#               0.3536,
#               0.1826,
#               0.3162,
#               0.2673,
#               0.2673,
#               0.3162,
#               0.3162,
#               0.2582,
#               0.7071,
#               0.2294,
#               0.2236,
#               0.2357,
#               0.2041,
#               0.2041,
#               0.3162,
#               0.2582,
#               0.2357,
#               0.3333,
#               0.3015,
#               0.3162,
#               0.3162,
#               0.2774,
#               0.2236,
#               0.3162,
#               0.3162,
#               0.1961,
#               0.3536],
#              'fascist': [0.2887,
#               0.25,
#               0.4082,
#               0.2357,
#               0.378,
#               0.1925,
#               0.4472,
#               0.3536,
#               0.2294],
#              'russia': [0.2887,
#               0.2673,
#               0.4714,
#               0.8528,
#               0.3536,
#               0.2887,
#               0.2085,
#               0.2673,
#               0.3333,
#               0.3162,
#               0.2887,
#               0.2236,
#               0.2357,
#               0.1857,
#               0.3015,
#               0.4,
#               0.3015,
#               0.25,
#               0.7071,
#               0.2774,
#               1.0,
#               0.4,
#               0.2236,
#               0.3333,
#               0.3015,
#               0.3592,
#               0.1741,
#               0.2425,
#               0.5222,
#               0.2673,
#               0.3015,
#               0.2425,
#               0.3162,
#               0.378,
#               0.4082,
#               0.2357,
#               0.7276,
#               0.2774,
#               0.378,
#               0.2236,
#               0.3162,
#               0.2887,
#               0.3162,
#               0.3015,
#               0.2132,
#               0.25,
#               0.3536,
#               0.2041,
#               0.3015,
#               0.3162,
#               0.4082,
#               0.2425,
#               0.2236,
#               0.2673,
#               0.2582,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.3333,
#               0.2582,
#               0.2132,
#               0.378,
#               0.2425,
#               0.2357,
#               0.1961,
#               0.5164,
#               0.2582,
#               0.2582,
#               0.1741,
#               0.2,
#               0.2182,
#               0.2887,
#               0.3015,
#               0.5,
#               0.3849,
#               0.3536,
#               0.2887,
#               0.7071,
#               0.2774,
#               0.3536,
#               0.5303,
#               0.2357,
#               0.5303,
#               0.2582,
#               0.2582,
#               0.1826,
#               0.4472,
#               0.2673,
#               0.1925,
#               0.3333,
#               0.3162,
#               0.2236,
#               0.2582,
#               0.5388,
#               0.378,
#               0.2774,
#               0.2887,
#               0.2887,
#               0.2887,
#               0.3536,
#               0.4472,
#               0.4472,
#               0.3162,
#               0.3333,
#               0.3015,
#               0.3536,
#               0.3536,
#               0.2294,
#               0.2236,
#               0.3536,
#               0.2582,
#               0.3536,
#               0.378,
#               0.25,
#               0.2294,
#               0.3162,
#               0.2132,
#               0.3015,
#               0.2182,
#               0.2582,
#               0.2041,
#               0.2673,
#               0.3536,
#               0.4264,
#               0.3333,
#               0.2085,
#               0.3015,
#               0.189,
#               0.2673,
#               0.3162,
#               0.4082,
#               0.3015,
#               0.25,
#               0.2085,
#               0.1826,
#               0.3333,
#               0.2425,
#               0.2425,
#               0.4472,
#               0.2236,
#               0.2774,
#               0.1925,
#               0.3162,
#               0.2887,
#               0.5477,
#               0.2,
#               0.1826,
#               0.4264,
#               0.2294,
#               0.3162,
#               0.2294,
#               0.4082,
#               0.5774,
#               0.2132,
#               0.2887,
#               0.2,
#               0.3536,
#               0.4472,
#               0.2887,
#               0.3015,
#               0.378,
#               0.2357,
#               0.4082,
#               0.2294,
#               0.189,
#               0.4588,
#               0.2357,
#               0.2673,
#               0.3015,
#               0.3162,
#               0.189,
#               0.2887,
#               0.4082,
#               0.2182,
#               0.2425,
#               0.2085,
#               0.3922,
#               0.3015,
#               0.2582,
#               0.3015,
#               0.4082,
#               0.3482,
#               0.3922,
#               0.2041,
#               0.3162,
#               0.189,
#               0.4082,
#               0.25,
#               0.5,
#               0.378,
#               0.3015,
#               0.1961,
#               0.1925,
#               0.2887,
#               0.4082,
#               0.3536,
#               0.1826,
#               0.3015,
#               0.1925,
#               0.2294,
#               0.2,
#               0.378,
#               0.2294,
#               0.4472,
#               0.3162,
#               0.2774,
#               0.2357,
#               0.2236,
#               0.3162,
#               0.2132,
#               0.2132,
#               0.3333,
#               0.378,
#               0.2182,
#               0.2774,
#               0.3536,
#               0.1796,
#               0.2182,
#               0.2357,
#               0.3162,
#               0.3162,
#               0.3015,
#               0.3333,
#               0.3015,
#               0.3536,
#               0.3536,
#               0.2294,
#               0.3333,
#               0.378,
#               0.5,
#               0.2236,
#               0.4472,
#               0.2425,
#               0.2887,
#               0.1961,
#               0.3536,
#               0.3333,
#               0.3015,
#               0.5774,
#               0.3015,
#               0.25,
#               0.2887,
#               0.3086,
#               0.2294,
#               0.2041,
#               0.3162,
#               0.2425,
#               0.2236,
#               0.3015,
#               0.2582,
#               0.2774,
#               0.2357,
#               0.2582,
#               0.603,
#               0.3015,
#               0.3333,
#               0.378,
#               0.2236,
#               0.3333,
#               0.2294,
#               0.3203,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.3015,
#               0.2425,
#               0.2425,
#               0.3333,
#               0.2132,
#               0.3162,
#               0.25,
#               0.4588,
#               0.3015,
#               0.3536,
#               0.2294,
#               0.2357,
#               0.5774,
#               0.4472,
#               0.2357,
#               0.378,
#               0.378,
#               0.378,
#               0.378,
#               0.3015,
#               0.2887,
#               0.2582,
#               0.3333,
#               0.2673,
#               0.3162,
#               0.2294,
#               0.2582,
#               0.3333,
#               0.25,
#               0.2887,
#               0.4472,
#               0.2774,
#               0.3536,
#               0.2774,
#               0.1741,
#               0.603,
#               0.378,
#               0.5774,
#               0.3536,
#               0.3015,
#               0.3162,
#               0.3162,
#               0.378,
#               0.3536,
#               0.2236,
#               0.2294,
#               0.3162,
#               0.25,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.4082,
#               0.2887,
#               0.4364,
#               0.2774,
#               0.2887,
#               0.4714,
#               0.4714,
#               0.2887,
#               0.2774,
#               0.3162,
#               0.3015,
#               0.3333,
#               0.378,
#               0.3015,
#               0.3536,
#               0.3536,
#               0.2294,
#               0.3333,
#               0.3849,
#               0.4472,
#               0.3162,
#               0.3162,
#               0.1581,
#               0.2887,
#               0.3015,
#               0.3162,
#               0.2887,
#               0.2294,
#               0.2132,
#               0.2774,
#               0.2236,
#               0.2182,
#               0.2887,
#               0.2887,
#               0.5,
#               0.3162,
#               0.5774,
#               0.3162,
#               0.3162,
#               0.2582,
#               0.4472,
#               0.4472,
#               0.3922,
#               0.3015,
#               0.3536,
#               0.2582,
#               0.3922,
#               0.378,
#               0.3015,
#               0.2357,
#               0.2041,
#               0.378,
#               0.4472,
#               0.2425,
#               0.2887,
#               0.2182,
#               0.3162,
#               0.2041,
#               0.4472,
#               0.3162,
#               0.2582,
#               0.4082,
#               0.1961,
#               0.2887,
#               0.25,
#               0.5774,
#               0.2132,
#               0.2357,
#               0.4082,
#               0.4082,
#               0.2132,
#               0.1741,
#               0.2887,
#               0.3333,
#               0.3162,
#               0.2887,
#               0.2357,
#               0.2357,
#               0.603,
#               0.25,
#               0.2,
#               0.4082,
#               0.2857,
#               0.2887,
#               0.3015,
#               0.378,
#               0.2085,
#               0.2041,
#               0.2132,
#               0.2041,
#               0.3536,
#               0.3536,
#               0.2425,
#               0.3536,
#               0.3162,
#               0.3162,
#               0.2887,
#               0.378,
#               0.378,
#               0.2673,
#               0.378,
#               0.2132,
#               0.2041,
#               0.3333,
#               0.2357,
#               0.3162,
#               0.3162,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.3162,
#               0.2887,
#               0.3536,
#               0.3162,
#               0.2294,
#               0.378,
#               0.25,
#               0.2357,
#               0.2182,
#               0.3333,
#               0.189,
#               0.378,
#               0.3536,
#               0.2774,
#               0.3922,
#               0.1961,
#               0.1768,
#               0.2673,
#               0.2085,
#               0.2294,
#               0.1961,
#               0.2673,
#               0.2357,
#               0.5,
#               0.3536,
#               0.2425,
#               0.2673,
#               0.2425,
#               0.2357,
#               0.378,
#               0.1768,
#               0.2673,
#               0.378,
#               0.25,
#               0.2294,
#               0.2949,
#               0.2294,
#               0.4588,
#               0.4082,
#               0.2294,
#               0.2085,
#               0.2041,
#               0.4472,
#               0.5898,
#               0.1857,
#               0.2182,
#               0.25,
#               0.2085,
#               0.25,
#               0.3015,
#               0.378,
#               0.4472,
#               0.5477,
#               0.3015,
#               0.1961,
#               0.3333,
#               0.3162,
#               0.2085,
#               0.2673],
#              'intend': [0.2887, 0.2673, 0.2294, 0.3536, 0.2357],
#              'conquer': [0.2887, 0.2041],
#              'much': [0.2887,
#               0.2294,
#               0.2774,
#               0.189,
#               0.4472,
#               0.3333,
#               0.378,
#               0.2236,
#               0.25,
#               0.2294,
#               0.2132,
#               0.2294,
#               0.2357,
#               0.2182,
#               0.2182,
#               0.2774,
#               0.5774,
#               0.4082,
#               0.2774,
#               0.1741,
#               0.2,
#               0.2425,
#               0.25,
#               0.3536,
#               0.1857,
#               0.2085,
#               0.3333,
#               0.2085],
#              'ukrainian': [0.2887,
#               0.2774,
#               0.2887,
#               0.3333,
#               0.2887,
#               0.2085,
#               0.3536,
#               0.3015,
#               0.2294,
#               0.3162,
#               0.378,
#               0.2887,
#               0.2,
#               0.2582,
#               0.2132,
#               0.2673,
#               0.2236,
#               0.2,
#               0.5774,
#               0.2236,
#               0.3922,
#               0.2085,
#               0.2,
#               0.3536,
#               0.3162,
#               0.5774,
#               0.1857,
#               0.1796,
#               0.4472,
#               0.1741,
#               0.3536,
#               0.5774,
#               0.1796,
#               0.3015,
#               0.2425,
#               0.2357,
#               0.378,
#               0.3333,
#               0.2774,
#               0.3333,
#               0.3162,
#               0.2673,
#               0.3536,
#               0.2887,
#               0.3015,
#               0.3015,
#               0.25,
#               0.3333,
#               0.3162,
#               0.2582,
#               0.3536,
#               0.3015,
#               0.3536,
#               0.25,
#               0.1925,
#               0.2294,
#               0.3333,
#               0.3536,
#               0.4082,
#               0.4082,
#               0.2887,
#               0.3162,
#               0.2582,
#               0.3015,
#               0.2774,
#               0.2236,
#               0.5774,
#               0.378,
#               0.1925,
#               0.2887,
#               0.2774,
#               0.6882,
#               0.3333,
#               0.2357,
#               0.2774,
#               0.1925,
#               0.3333,
#               0.4082,
#               0.2774,
#               0.3333,
#               0.2887,
#               0.3333,
#               0.4472,
#               0.2582,
#               0.3015,
#               0.2887,
#               0.2887,
#               0.2774,
#               0.378,
#               0.378,
#               0.189,
#               0.3015,
#               0.3162,
#               0.2774,
#               0.3333,
#               0.3536,
#               0.2887,
#               0.1667,
#               0.2887,
#               0.25,
#               0.4082,
#               0.5774,
#               0.2774,
#               0.3015,
#               0.2236,
#               0.2085,
#               0.3333,
#               0.2673,
#               0.2182,
#               0.2294,
#               0.2774,
#               0.2425,
#               0.2582,
#               0.3536,
#               0.7071,
#               0.378,
#               0.3162,
#               0.2425,
#               0.4472,
#               0.2887,
#               0.2357,
#               0.2357,
#               0.2294,
#               0.2041,
#               0.2357,
#               0.5547,
#               0.3162,
#               0.378,
#               0.4472,
#               0.3333,
#               0.3333,
#               0.3333,
#               0.3162,
#               0.2294,
#               0.5,
#               0.3333,
#               0.3333,
#               0.2294,
#               0.2582,
#               0.2294,
#               0.4472,
#               0.2085,
#               0.2294,
#               0.2582,
#               0.3333,
#               0.3333,
#               0.378,
#               0.4264,
#               0.3333,
#               0.3162,
#               0.378,
#               0.2425,
#               0.2357,
#               0.25,
#               0.2294,
#               0.4082,
#               0.2294,
#               0.3015,
#               0.3333,
#               0.378,
#               0.4472,
#               0.2774,
#               0.2774,
#               0.2357,
#               0.378,
#               0.3536,
#               0.3536,
#               0.4082,
#               0.3015,
#               0.2041,
#               0.3333,
#               0.3015,
#               0.2294,
#               0.2887,
#               0.1925,
#               0.2085,
#               0.2673,
#               0.3015,
#               0.2887,
#               0.2887,
#               0.2041,
#               0.2774,
#               0.3333,
#               0.2425,
#               0.3536,
#               0.3015,
#               0.5,
#               0.2774,
#               0.3333,
#               0.4472,
#               0.2774,
#               0.2,
#               0.2887,
#               0.2294,
#               0.2582,
#               0.4472,
#               0.7071,
#               0.2357,
#               0.378,
#               0.2582,
#               0.2887,
#               0.3015,
#               0.378,
#               0.5774,
#               0.3162,
#               0.3162,
#               0.3536,
#               0.3162,
#               0.4082,
#               0.378,
#               0.1313,
#               0.1826,
#               0.3333,
#               0.2,
#               0.3536,
#               0.25,
#               0.3536,
#               0.3714,
#               0.4082,
#               0.4082,
#               0.378,
#               0.3536,
#               0.5,
#               0.378,
#               0.3536,
#               0.3536,
#               0.2182,
#               0.3333,
#               0.378,
#               0.3536,
#               0.3536,
#               0.3536,
#               0.3333,
#               0.4472,
#               0.2774,
#               0.2357,
#               0.378,
#               0.2673,
#               0.378,
#               0.2673,
#               0.4472,
#               0.3536,
#               0.3015,
#               0.2673,
#               0.3536,
#               0.4082,
#               0.3333,
#               0.2357,
#               0.2582,
#               0.433,
#               0.2357,
#               0.378,
#               0.4082,
#               0.603,
#               0.4472,
#               0.3536,
#               0.1857,
#               0.3333,
#               0.4472,
#               0.1826,
#               0.25,
#               0.189,
#               0.4082,
#               0.3162,
#               0.3015,
#               0.3015,
#               0.6667,
#               0.5,
#               0.2294,
#               0.6,
#               0.1826,
#               0.417,
#               0.2887,
#               0.2182,
#               0.3333,
#               0.2582,
#               0.3015,
#               0.2887,
#               0.3333,
#               0.3015,
#               0.6124,
#               0.3536,
#               0.3015,
#               0.2887,
#               0.2887,
#               0.3922,
#               0.2774,
#               0.3162,
#               0.2673,
#               0.2425,
#               0.4082,
#               0.2,
#               0.2887,
#               0.2582,
#               0.3015,
#               0.3333,
#               0.378,
#               0.3162,
#               0.378,
#               0.2357,
#               0.5164,
#               0.2887,
#               0.378,
#               0.378,
#               0.2132,
#               0.4472,
#               0.3162,
#               0.2887,
#               0.2294,
#               0.603,
#               0.6708,
#               0.2132,
#               0.3333,
#               0.3162,
#               0.2132,
#               0.3333,
#               0.3015,
#               0.3015,
#               0.3162,
#               0.25,
#               0.3162,
#               0.378,
#               0.2357,
#               0.3015,
#               0.3162,
#               0.4472,
#               0.3536,
#               0.3015,
#               0.378,
#               0.2774,
#               0.378,
#               0.3536,
#               0.378,
#               0.378,
#               0.378,
#               0.378,
#               0.378,
#               0.4851,
#               0.3333,
#               0.2041,
#               0.4082,
#               0.3333,
#               0.3536,
#               0.2887,
#               0.3536,
#               0.3333,
#               0.4082,
#               0.2887,
#               0.5,
#               0.3536,
#               0.3849,
#               0.3162,
#               0.2673,
#               0.2182,
#               0.3162,
#               0.4082,
#               0.3015,
#               0.189,
#               0.3015,
#               0.3333,
#               0.6325,
#               0.3333,
#               0.25,
#               0.2774,
#               0.4,
#               0.1429,
#               0.2673,
#               0.3333,
#               0.2774,
#               0.25,
#               0.2673,
#               0.2673,
#               0.3015,
#               0.3536,
#               0.25,
#               0.2132,
#               0.2132,
#               0.2887,
#               0.2425,
#               0.2774,
#               0.3333,
#               0.3333,
#               0.3333,
#               0.2182,
#               0.2,
#               0.1325,
#               0.2085,
#               0.3536,
#               0.378,
#               0.7071,
#               0.2582,
#               0.2357,
#               0.3536,
#               0.2582,
#               0.2357,
#               0.4264,
#               0.2887,
#               0.2774,
#               0.2887,
#               0.2774,
#               0.2887,
#               0.2132,
#               0.2582,
#               0.2582,
#               0.4472,
#               0.2582,
#               0.378,
#               0.5774,
#               0.5,
#               0.2236,
#               0.2673,
#               0.3333,
#               0.2085,
#               0.3162,
#               0.3162,
#               0.2357,
#               0.2887,
#               0.2132,
#               0.3536,
#               0.2582,
#               0.4472,
#               0.4472,
#               0.378,
#               0.3015,
#               0.2132,
#               0.1925,
#               0.1857,
#               0.5,
#               0.3536,
#               0.2236,
#               0.2236,
#               0.1741,
#               0.25,
#               0.2294,
#               0.2085],
#              'land': [0.2887,
#               0.4714,
#               0.189,
#               0.2236,
#               0.2182,
#               0.1857,
#               0.2673,
#               0.4364,
#               0.2357,
#               0.1768,
#               0.1768,
#               0.1826,
#               0.3536,
#               0.2182,
#               0.1796,
#               0.25,
#               0.2132,
#               0.2132,
#               0.2132,
#               0.2887,
#               0.2673,
#               0.2673,
#               0.2673,
#               0.2673,
#               0.2673,
#               0.1562,
#               0.25,
#               0.25,
#               0.25,
#               0.25,
#               0.2132,
#               0.2041,
#               0.3536,
#               0.2425,
#               0.2132,
#               0.3536,
#               0.5477,
#               0.3162,
#               0.4472,
#               0.3333,
#               0.3162,
#               0.2425,
#               0.2182,
#               0.2182,
#               0.4082,
#               0.189,
#               0.2,
#               0.4082,
#               0.2294,
#               0.2887,
#               0.2085,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.1644,
#               0.3333,
#               0.378,
#               0.2673,
#               0.3333,
#               0.2182,
#               0.2182,
#               0.3714,
#               0.3333],
#              'possibl': [0.2887,
#               0.2582,
#               0.2774,
#               0.1925,
#               0.2582,
#               0.3162,
#               0.2425,
#               0.3536,
#               0.4472,
#               0.1961,
#               0.2357,
#               0.2774,
#               0.3162,
#               0.3333,
#               0.2425,
#               0.4472,
#               0.25,
#               0.2887,
#               0.2887,
#               0.4472,
#               0.2132,
#               0.2357,
#               0.2582,
#               0.2582,
#               0.2887,
#               0.3162,
#               0.2182,
#               0.4082,
#               0.2582,
#               0.2887,
#               0.2425,
#               0.1961,
#               0.1768,
#               0.2887,
#               0.3162,
#               0.2673],
#              'arm': [0.3536,
#               0.3536,
#               0.3536,
#               0.2182,
#               0.3333,
#               0.3333,
#               0.5,
#               0.378,
#               0.4082,
#               0.5,
#               0.2582,
#               0.5774,
#               0.3536,
#               0.3536,
#               0.2357,
#               0.2774,
#               0.3333,
#               0.2774,
#               0.2582,
#               0.2582,
#               0.2673,
#               0.2041,
#               0.25,
#               0.2673,
#               0.3015,
#               0.1961,
#               0.2774,
#               0.2673,
#               0.5,
#               0.2887,
#               0.2582,
#               0.2582,
#               0.4082,
#               0.2425,
#               0.2774,
#               0.2357,
#               0.2887,
#               0.3162,
#               0.378,
#               0.2357,
#               0.2294,
#               0.2085,
#               0.2294,
#               0.2182,
#               0.378,
#               0.2041,
#               0.3162,
#               0.378,
#               0.3162,
#               0.4082,
#               0.4082,
#               0.3015,
#               0.3333,
#               0.2887,
#               0.2887,
#               0.2887,
#               0.4082,
#               0.4082,
#               0.2673,
#               0.3015,
#               0.5,
#               0.2582,
#               0.3015,
#               0.3015,
#               0.3015,
#               0.2887,
#               0.2,
#               0.3015,
#               0.2041,
#               0.1961,
#               0.2673,
#               0.2425,
#               0.4472,
#               0.2887,
#               0.2132,
#               0.3015,
#               0.3536,
#               0.378,
#               0.3162,
#               0.3162,
#               0.2887,
#               0.2582,
#               0.2357,
#               0.2357,
#               0.2425,
#               0.4264,
#               0.4264,
#               0.3333,
#               0.4264,
#               0.4,
#               0.4082,
#               0.2041,
#               0.2182,
#               0.3015,
#               0.5,
#               0.25,
#               0.2887,
#               0.3333,
#               0.4082,
#               0.3536,
#               0.2182,
#               0.3333,
#               0.3333,
#               0.2357,
#               0.3536],
#              'forc': [0.3536,
#               0.2774,
#               0.3536,
#               0.2425,
#               0.3536,
#               0.189,
#               0.2132,
#               0.2774,
#               0.1857,
#               0.3015,
#               0.3536,
#               0.2,
#               0.3015,
#               0.4472,
#               0.2182,
#               0.3015,
#               0.3333,
#               0.3015,
#               0.2294,
#               0.3536,
#               0.5,
#               0.2774,
#               0.378,
#               0.4082,
#               0.2774,
#               0.3162,
#               0.2294,
#               0.5,
#               0.2582,
#               0.378,
#               0.2774,
#               0.5774,
#               0.4851,
#               0.3015,
#               0.1925,
#               0.2582,
#               0.3333,
#               0.3536,
#               0.2357,
#               0.2357,
#               0.2774,
#               0.2182,
#               0.2236,
#               0.378,
#               0.1961,
#               0.2182,
#               0.2887,
#               0.3015,
#               0.189,
#               0.2582,
#               0.4082,
#               0.4472,
#               0.2887,
#               0.5,
#               0.25,
#               0.2673,
#               0.2887,
#               0.5547,
#               0.3015,
#               0.25,
#               0.2887,
#               0.3536,
#               0.7071,
#               0.1961,
#               0.5,
#               0.3015,
#               0.3015,
#               0.2887,
#               0.2774,
#               0.2673,
#               0.5,
#               0.3536,
#               0.2132,
#               0.2887,
#               0.3015,
#               0.2673,
#               0.2357,
#               0.2041,
#               0.2357,
#               0.2582,
#               0.2582,
#               0.4082,
#               0.2582,
#               0.3536,
#               0.2425,
#               0.5774,
#               0.2774,
#               0.4472,
#               0.2582,
#               0.3536,
#               0.5,
#               0.2357,
#               0.2294,
#               0.4082,
#               0.3333,
#               0.5,
#               0.4472,
#               0.378,
#               0.2887,
#               0.3162,
#               0.25,
#               0.2887,
#               0.3162,
#               0.378,
#               0.3162,
#               0.2357,
#               0.1961,
#               0.2425,
#               0.2294,
#               0.2294,
#               0.5774,
#               0.1961,
#               0.2774,
#               0.2041,
#               0.378,
#               0.4472,
#               0.2887,
#               0.2041,
#               0.3015,
#               0.2085,
#               0.378,
#               0.4082,
#               0.3536,
#               0.4082,
#               0.3015,
#               0.2236,
#               0.2582,
#               0.2357,
#               0.3333,
#               0.2887,
#               0.2132,
#               0.5774,
#               0.3162,
#               0.378,
#               0.4082,
#               0.4082,
#               0.3015,
#               0.5,
#               0.5,
#               0.5,
#               0.3536,
#               0.25,
#               0.2132,
#               0.2774,
#               0.2357,
#               0.2673,
#               0.2774,
#               0.5,
#               0.4472,
#               0.3015,
#               0.5164,
#               0.4082,
#               0.3015,
#               0.1443,
#               0.378,
#               0.3015,
#               0.2774,
#               0.3333,
#               0.2294,
#               0.2,
#               0.2774,
#               0.378,
#               0.3015,
#               0.2041,
#               0.2887,
#               0.3015,
#               0.1961,
#               0.2673,
#               0.2425,
#               0.2,
#               0.25,
#               0.3015,
#               0.2236,
#               0.2887,
#               0.2132,
#               0.3015,
#               0.2357,
#               0.3162,
#               0.3162,
#               0.4082,
#               0.3162,
#               0.3333,
#               0.2294,
#               0.3015,
#               0.378,
#               0.2357,
#               0.3333,
#               0.1925,
#               0.2774,
#               0.189,
#               0.2041,
#               0.3162,
#               0.2425,
#               0.3162,
#               0.3536,
#               0.2887,
#               0.4472,
#               0.1961,
#               0.2041,
#               0.3714,
#               0.2236,
#               0.378,
#               0.2774,
#               0.2357,
#               0.2887,
#               0.2357,
#               0.2425,
#               0.3162,
#               0.2132,
#               0.2774,
#               0.3333,
#               0.2132,
#               0.3333,
#               0.3333,
#               0.4264,
#               0.4,
#               0.2085,
#               0.4082,
#               0.417,
#               0.2182,
#               0.3015,
#               0.4364,
#               0.2357,
#               0.2774,
#               0.3015,
#               0.3015,
#               0.5,
#               0.3015,
#               0.2673,
#               0.378,
#               0.25,
#               0.2425,
#               0.2887,
#               0.3333,
#               0.4082,
#               0.378,
#               0.5774,
#               0.3333,
#               0.4714,
#               0.189,
#               0.3333,
#               0.2582,
#               0.3536,
#               0.2236,
#               0.3015,
#               0.2673,
#               0.3123,
#               0.3162,
#               0.3015,
#               0.2357,
#               0.3536,
#               0.2887,
#               0.2887,
#               0.2294,
#               0.2085,
#               0.189],
#              'liber': [0.3536,
#               0.3536,
#               0.2294,
#               0.3015,
#               0.2085,
#               0.2425,
#               0.4472,
#               0.2887,
#               0.2294,
#               0.2582,
#               0.3333,
#               0.2774,
#               0.3015,
#               0.2774,
#               0.2236,
#               0.1768,
#               0.4472,
#               0.4472,
#               0.4082,
#               0.2774,
#               0.2887,
#               0.2357,
#               0.2357,
#               0.4082,
#               0.3015,
#               0.2774,
#               0.3015,
#               0.2,
#               0.1826,
#               0.2041,
#               0.1961,
#               0.2774,
#               0.3015,
#               0.3015,
#               0.3333,
#               0.4082,
#               0.7071,
#               0.2,
#               0.2236,
#               0.2774,
#               0.3536,
#               0.2887,
#               0.3536,
#               0.2294],
#              'villag': [0.3536,
#               0.3536,
#               0.25,
#               0.3333,
#               0.2294,
#               0.2132,
#               0.2357,
#               0.2774,
#               0.3015,
#               0.378,
#               0.378,
#               0.1961,
#               0.25,
#               0.4714],
#              'urban': [0.3536, 0.2294],
#              'territori': [0.3536,
#               0.2673,
#               0.2774,
#               0.1741,
#               0.3015,
#               0.3162,
#               0.2887,
#               0.2085,
#               0.3536,
#               0.3162,
#               0.3162,
#               0.2425,
#               0.2,
#               0.3922,
#               0.2774,
#               0.3482,
#               0.2673,
#               0.2425,
#               0.2774,
#               0.2774,
#               0.3162,
#               0.2294,
#               0.3015,
#               0.6124,
#               0.3536,
#               0.378,
#               0.378,
#               0.3333,
#               0.3536,
#               0.3015,
#               0.2182,
#               0.2182,
#               0.2582,
#               0.2132,
#               0.378,
#               0.2425,
#               0.3162,
#               0.2582,
#               0.2887,
#               0.2887,
#               0.378,
#               0.2294,
#               0.1925,
#               0.4082,
#               0.2774,
#               0.2357,
#               0.2673,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.2182,
#               0.2294,
#               0.2673,
#               0.2357,
#               0.2357,
#               0.1925,
#               0.378,
#               0.4472,
#               0.2041,
#               0.2582,
#               0.4082,
#               0.2294,
#               0.2887,
#               0.4082,
#               0.2236,
#               0.25,
#               0.2236,
#               0.4082,
#               0.3333,
#               0.3333,
#               0.2887,
#               0.3333,
#               0.2294,
#               0.2887,
#               0.3333,
#               0.1796,
#               0.2673,
#               0.25,
#               0.2041,
#               0.2774,
#               0.3162,
#               0.3015,
#               0.2294,
#               0.2774,
#               0.2887,
#               0.2294,
#               0.2294,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.378,
#               0.3015,
#               0.3333,
#               0.3536,
#               0.4364,
#               0.2132,
#               0.25,
#               0.2357,
#               0.2673,
#               0.2887,
#               0.3536,
#               0.3536,
#               0.2294,
#               0.2357,
#               0.2425,
#               0.3015,
#               0.2132,
#               0.3015,
#               0.2673,
#               0.1826,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2236,
#               0.2182,
#               0.2357,
#               0.3333,
#               0.2041,
#               0.25,
#               0.2887,
#               0.25,
#               0.2294,
#               0.3015,
#               0.2357,
#               0.2425,
#               0.3536,
#               0.2085,
#               0.4472,
#               0.378,
#               0.4082,
#               0.25,
#               0.2,
#               0.2041,
#               0.2236,
#               0.4082,
#               0.3922,
#               0.2357,
#               0.2425,
#               0.2357,
#               0.2085,
#               0.4082,
#               0.2357,
#               0.2673,
#               0.2673,
#               0.2041,
#               0.25,
#               0.2085,
#               0.378],
#              'commun': [0.3536,
#               0.2425,
#               0.2182,
#               0.1961,
#               0.2236,
#               0.2085,
#               0.2887,
#               0.2,
#               0.2041,
#               0.2294,
#               0.3015,
#               0.3015,
#               0.2,
#               0.2182,
#               0.1961,
#               0.2041,
#               0.3333,
#               0.1622],
#              'regionukrainerussiawar': [0.3536],
#              'alert': [0.378,
#               0.2673,
#               0.4082,
#               0.2582,
#               0.189,
#               0.7071,
#               0.2236,
#               0.5,
#               0.4082,
#               0.3015,
#               0.3333],
#              'poland': [0.378,
#               0.5774,
#               0.2085,
#               0.2294,
#               0.1826,
#               0.2182,
#               0.1543,
#               0.3651,
#               0.4082,
#               0.2673,
#               0.378,
#               0.2357,
#               0.2182,
#               0.2,
#               0.3162,
#               0.1961,
#               0.25],
#              'prep': [0.378],
#              'antiradi': [0.378],
#              'tablet': [0.378],
#              'nuclear': [0.378,
#               0.2085,
#               0.4082,
#               0.4082,
#               0.3849,
#               0.3922,
#               0.3536,
#               0.4,
#               0.3333,
#               0.2887,
#               0.2357,
#               0.3333,
#               0.2774,
#               0.1925,
#               0.2774,
#               0.2673,
#               0.3162,
#               0.3333,
#               0.2887,
#               0.3536,
#               0.378,
#               0.2294,
#               0.378,
#               0.3922,
#               0.2582,
#               0.2132,
#               0.2,
#               0.3333,
#               0.2774,
#               0.3333,
#               0.3333,
#               0.3333,
#               0.189,
#               0.378,
#               0.7071,
#               0.3162,
#               0.4082,
#               0.2085,
#               0.3015,
#               0.2357,
#               0.2236,
#               0.3333,
#               0.2182,
#               0.2425,
#               0.2041,
#               0.2357,
#               0.3333,
#               0.3015,
#               0.2425,
#               0.4472,
#               0.378,
#               0.25,
#               0.2673,
#               0.3536,
#               0.3333,
#               0.3536,
#               0.3015,
#               0.2887,
#               0.2887,
#               0.25,
#               0.2887,
#               0.3015,
#               0.4472,
#               0.2673,
#               0.2425,
#               0.2774,
#               0.3015,
#               0.1768,
#               0.2887,
#               0.2132,
#               0.2182,
#               0.2132,
#               0.2085,
#               0.2582,
#               0.5,
#               0.2236,
#               0.2041,
#               0.25,
#               0.3333,
#               0.1715,
#               0.2085,
#               0.2673,
#               0.3333,
#               0.2132,
#               0.3536,
#               0.2132,
#               0.2294,
#               0.2041,
#               0.3849,
#               0.3536,
#               0.1768,
#               0.2132,
#               0.378,
#               0.4472,
#               0.2236,
#               0.25,
#               0.2582,
#               0.25,
#               0.3162],
#              'threat': [0.378,
#               0.1147,
#               0.2774,
#               0.2294,
#               0.2357,
#               0.378,
#               0.3162,
#               0.1826,
#               0.3015,
#               0.3015,
#               0.2294,
#               0.2357,
#               0.3162,
#               0.3015,
#               0.2294,
#               0.3333,
#               0.3536,
#               0.3015,
#               0.2887,
#               0.2132,
#               0.3162,
#               0.25,
#               0.2887,
#               0.4472,
#               0.3015,
#               0.2357,
#               0.5,
#               0.2236,
#               0.2357,
#               0.3333,
#               0.3536,
#               0.2236,
#               0.2425,
#               0.3333,
#               0.25,
#               0.2887,
#               0.2132,
#               0.4588,
#               0.3162],
#              'im': [0.2673,
#               0.2294,
#               0.2357,
#               0.2132,
#               0.1826,
#               0.3162,
#               0.3015,
#               0.1925,
#               0.2041,
#               0.1961,
#               0.1961,
#               0.2425,
#               0.3536,
#               0.2357],
#              'still': [0.2673,
#               0.2774,
#               0.1961,
#               0.4082,
#               0.2673,
#               0.2132,
#               0.2182,
#               0.2132,
#               0.2085,
#               0.3536,
#               0.4364,
#               0.1925,
#               0.189,
#               0.2582,
#               0.2132,
#               0.4082,
#               0.2236,
#               0.189,
#               0.2085,
#               0.2582,
#               0.1601,
#               0.25,
#               0.4082,
#               0.2357,
#               0.25,
#               0.1741,
#               0.2132,
#               0.2132,
#               0.2236,
#               0.2425,
#               0.2132,
#               0.2132,
#               0.3333,
#               0.3015,
#               0.4082],
#              'wait': [0.2673,
#               0.5774,
#               0.25,
#               0.3333,
#               0.2887,
#               0.2425,
#               0.1857,
#               0.2294,
#               0.2425,
#               0.5,
#               0.2236,
#               0.25,
#               0.378,
#               0.2236,
#               0.4472,
#               0.3162,
#               0.2774,
#               0.4082,
#               0.3536],
#              'googl': [0.2673, 0.5774],
#              'map': [0.2673,
#               0.2673,
#               0.5,
#               0.2236,
#               0.3015,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.25,
#               0.2673,
#               0.378,
#               0.3333,
#               0.378,
#               0.4082,
#               0.2182,
#               0.2085,
#               0.2,
#               0.2357,
#               0.4082,
#               0.4472,
#               0.4472,
#               0.2085,
#               0.3333,
#               0.378,
#               0.4082,
#               0.3162],
#              'updat': [0.2673,
#               0.2774,
#               0.5164,
#               0.5,
#               0.2357,
#               0.3015,
#               0.3536,
#               0.4082,
#               0.2582,
#               0.5,
#               0.7071,
#               0.7071,
#               0.4082,
#               0.2425,
#               0.1667,
#               0.2673,
#               0.3333,
#               0.2132,
#               0.3536,
#               0.2236,
#               0.378,
#               0.1961,
#               0.2182,
#               0.2673,
#               0.2673,
#               0.1826,
#               0.4082,
#               0.2774,
#               0.7071,
#               0.169,
#               0.2673,
#               0.2182,
#               0.2425,
#               0.5774,
#               0.7071,
#               0.2673,
#               0.3536,
#               0.3333,
#               0.3536],
#              'new': [0.2673,
#               0.5,
#               0.2673,
#               0.2357,
#               0.3536,
#               0.2,
#               0.3162,
#               0.2425,
#               0.3536,
#               0.2236,
#               0.3333,
#               0.2774,
#               0.4082,
#               0.5,
#               0.3162,
#               0.2582,
#               0.2887,
#               0.4082,
#               0.2774,
#               0.378,
#               0.25,
#               0.2294,
#               0.3333,
#               0.1925,
#               0.378,
#               0.2236,
#               0.2774,
#               0.3536,
#               0.3015,
#               0.2582,
#               0.2887,
#               0.2774,
#               0.378,
#               0.4082,
#               0.2357,
#               0.2887,
#               0.3536,
#               0.4472,
#               0.4472,
#               0.3015,
#               0.2425,
#               0.378,
#               0.3333,
#               0.2357,
#               0.2294,
#               0.4082,
#               0.2774,
#               0.3536,
#               0.2236,
#               0.2887,
#               0.1961,
#               0.3162,
#               0.4082,
#               0.4851,
#               0.4082,
#               0.3536,
#               0.189,
#               0.4082,
#               0.3162,
#               0.4472,
#               0.2774,
#               0.4082,
#               0.3536,
#               0.2582,
#               0.2582,
#               0.2357,
#               0.2887,
#               0.2357,
#               0.3015,
#               0.2673,
#               0.3333,
#               0.5345,
#               0.3015,
#               0.3015,
#               0.2887,
#               0.2294,
#               0.2182,
#               0.2774,
#               0.378,
#               0.25,
#               0.2425,
#               0.3015,
#               0.2582,
#               0.2425,
#               0.4472,
#               0.2774,
#               0.5,
#               0.25,
#               0.2774,
#               0.3333,
#               0.2132,
#               0.2425,
#               0.2887,
#               0.25,
#               0.2425,
#               0.3536,
#               0.2236,
#               0.3536,
#               0.2425,
#               0.3536,
#               0.3333,
#               0.378,
#               0.3333,
#               0.2673,
#               0.3536,
#               0.4082,
#               0.2582,
#               0.5,
#               0.4472,
#               0.3015,
#               0.2182,
# ...
#               0.2357,
#               0.3536,
#               0.2182,
#               0.2357,
#               0.2132],
#              'expos': [0.189, 0.5774, 0.4082, 0.2357, 0.3015],
#              'pandora': [0.189, 0.2887],
#              'paper': [0.189,
#               0.3015,
#               0.25,
#               0.25,
#               0.4472,
#               0.2887,
#               0.2236,
#               0.3536,
#               0.1741,
#               0.2357,
#               0.1768],
#              'ampnato': [0.189],
#              'sold': [0.189, 0.2673, 0.2673],
#              '3rd': [0.189, 0.1474],
#              'countriesukrain': [0.189],
#              'guard': [0.189,
#               0.1961,
#               0.416,
#               0.1961,
#               0.1961,
#               0.2085,
#               0.378,
#               0.3162,
#               0.3536,
#               0.3162,
#               0.2774,
#               0.2887,
#               0.25,
#               0.3015,
#               0.3015,
#               0.2582],
#              'spot': [0.189, 0.2673, 0.2774, 0.2774, 0.2582],
#              'two': [0.378,
#               0.2673,
#               0.1741,
#               0.5,
#               0.2041,
#               0.378,
#               0.2673,
#               0.5774,
#               0.3015,
#               0.2425,
#               0.2887,
#               0.2182,
#               0.2132,
#               0.25,
#               0.2425,
#               0.2236,
#               0.3536,
#               0.2085,
#               0.3015,
#               0.378,
#               0.3536,
#               0.2425,
#               0.2887,
#               0.2582,
#               0.2132,
#               0.3922,
#               0.2673,
#               0.378,
#               0.2582,
#               0.25,
#               0.378,
#               0.1826,
#               0.1961,
#               0.2582,
#               0.2887,
#               0.378,
#               0.2774,
#               0.2673,
#               0.3333,
#               0.2582,
#               0.3333,
#               0.2236,
#               0.3015,
#               0.25,
#               0.2887,
#               0.2294,
#               0.2582,
#               0.2236,
#               0.2132,
#               0.2132,
#               0.3333,
#               0.2673],
#              'silhouett': [0.189],
#              'shape': [0.189, 0.2582],
#              'behind': [0.189,
#               0.2774,
#               0.2425,
#               0.2887,
#               0.2887,
#               0.2357,
#               0.1925,
#               0.2236,
#               0.2673,
#               0.2357,
#               0.2774,
#               0.2085,
#               0.4082,
#               0.2294,
#               0.3162,
#               0.2774,
#               0.2887,
#               0.189],
#              'wild': [0.189, 0.2357],
#              'boar': [0.189],
#              'moldova': [0.189],
#              'young': [0.189,
#               0.2236,
#               0.4082,
#               0.3333,
#               0.2041,
#               0.169,
#               0.2582,
#               0.2673,
#               0.2887,
#               0.2294,
#               0.2294,
#               0.2294,
#               0.2294,
#               0.2294,
#               0.2294,
#               0.2294],
#              'draft': [0.189,
#               0.4082,
#               0.378,
#               0.25,
#               0.6405,
#               0.5,
#               0.378,
#               0.3333,
#               0.2887,
#               0.2673,
#               0.2085,
#               0.2132,
#               0.3536,
#               0.378,
#               0.2236,
#               0.3536,
#               0.2887,
#               0.3162,
#               0.2673,
#               0.3015,
#               0.3162,
#               0.189,
#               0.378,
#               0.378,
#               0.2673,
#               0.2132],
#              'age': [0.189,
#               0.3536,
#               0.3162,
#               0.2236,
#               0.1925,
#               0.1925,
#               0.378,
#               0.378,
#               0.2132,
#               0.2182,
#               0.5,
#               0.3333,
#               0.4472],
#              'getaway': [0.189],
#              'deni': [0.189,
#               0.3333,
#               0.1741,
#               0.3162,
#               0.2085,
#               0.2673,
#               0.3333,
#               0.1961],
#              'blast': [0.378, 0.5, 0.4472, 0.2357, 0.2085, 0.3536],
#              'outright': [0.378],
#              'satan': [0.378, 0.2236],
#              'secretari': [0.2,
#               0.2673,
#               0.2673,
#               0.2774,
#               0.2357,
#               0.2425,
#               0.189,
#               0.2887,
#               0.2774,
#               0.1741,
#               0.4714,
#               0.1925,
#               0.25,
#               0.2774,
#               0.2673,
#               0.2582,
#               0.3333,
#               0.2582,
#               0.25,
#               0.2357,
#               0.3015,
#               0.3162,
#               0.3015,
#               0.2085],
#              'retak': [0.2, 0.3333, 0.3333, 0.3333, 0.3333, 0.3333],
#              'blackmail': [0.2, 0.3849, 0.2182, 0.3536],
#              'convey': [0.2, 0.2236, 0.2236],
#              'ite': [0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082],
#              'pedicabo': [0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082],
#              'te': [0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082],
#              'ipsum': [0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082],
#              'latin': [0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.4082],
#              'friday': [0.2236,
#               0.2357,
#               0.2357,
#               0.2774,
#               0.2425,
#               0.2774,
#               0.2673,
#               0.2673,
#               0.2673,
#               0.3333,
#               0.2182,
#               0.3536,
#               0.2774,
#               0.2582,
#               0.2774,
#               0.5,
#               0.189,
#               0.2887,
#               0.3333,
#               0.2582,
#               0.2294,
#               0.2774],
#              'sever': [0.2236,
#               0.2294,
#               0.25,
#               0.3015,
#               0.2294,
#               0.4472,
#               0.2357,
#               0.25,
#               0.2085,
#               0.3536,
#               0.3536,
#               0.2085,
#               0.4082,
#               0.1826,
#               0.2582,
#               0.2887,
#               0.2887,
#               0.2294,
#               0.2887,
#               0.2774,
#               0.2582,
#               0.5,
#               0.2236],
#              'joe': [0.2236,
#               0.2182,
#               0.189,
#               0.2294,
#               0.3162,
#               0.3015,
#               0.2774,
#               0.25,
#               0.2425,
#               0.2673,
#               0.2132],
#              "moscow'": [0.2236, 0.2425, 0.2236],
#              'fraudul': [0.2236, 0.2182],
#              'run': [0.4082,
#               0.4472,
#               0.378,
#               0.2236,
#               0.7071,
#               0.378,
#               0.4472,
#               0.2887,
#               0.2673,
#               0.7276,
#               0.4082,
#               0.2132,
#               0.5774,
#               0.4082,
#               0.3714,
#               0.3162,
#               0.2425,
#               0.2774,
#               0.2887,
#               0.2182,
#               0.1796,
#               0.2887,
#               0.4,
#               0.3536,
#               0.2357,
#               0.4082,
#               0.1768,
#               0.2357,
#               0.2236],
#              'beschlossdc': [0.2582],
#              'sitdown': [0.2582],
#              'jordanbpeterson': [0.2582],
#              'media': [0.2582,
#               0.2294,
#               0.2887,
#               0.3333,
#               0.1961,
#               0.5774,
#               0.2774,
#               0.2582,
#               0.3714,
#               0.4472,
#               0.4082,
#               0.2182,
#               0.3162,
#               0.2294,
#               0.3333,
#               0.2774,
#               0.4082,
#               0.2774,
#               0.3015,
#               0.3536,
#               0.2294,
#               0.3015,
#               0.2357,
#               0.2582,
#               0.2236,
#               0.2085,
#               0.4264,
#               0.2,
#               0.25,
#               0.2294],
#              'celebr': [0.2582,
#               0.3333,
#               0.5,
#               0.3333,
#               0.2582,
#               0.2085,
#               0.2887,
#               0.2673,
#               0.2887,
#               0.2887,
#               0.2425,
#               0.25],
#              'seek': [0.2582, 0.2357, 0.3015, 0.2236, 0.3015, 0.2085, 0.25],
#              'offer': [0.2582,
#               0.3333,
#               0.3333,
#               0.3333,
#               0.2,
#               0.1961,
#               0.2357,
#               0.3536,
#               0.4714,
#               0.1768],
#              'excus': [0.2582, 0.4082],
#              'scum': [1.0, 0.3333, 0.2294, 0.8165],
#              'unequivoc': [0.1961, 0.2774, 0.2774, 0.2041, 0.2357],
#              'shout': [0.25, 0.2887],
#              'gangster': [0.25],
#              'bulli': [0.25, 0.2132, 0.3015, 0.3849, 0.2887],
#              'teenag': [0.25],
#              'postannex': [0.25],
#              'neighborhood': [0.25, 0.25],
#              'tragic': [0.25, 0.3162, 0.5],
#              'whistl': [0.25],
#              'walk': [0.25, 0.2182, 0.3333, 0.2357],
#              'cemeteri': [0.25],
#              'bad': [0.25,
#               0.2774,
#               0.1925,
#               0.3536,
#               0.2182,
#               0.2085,
#               0.2132,
#               0.2132,
#               0.2774],
#              'await': [0.25, 0.2085],
#              'awar': [0.25, 0.1961],
#              'livabl': [0.5],
#              'stoltenberg': [0.2673,
#               0.2673,
#               0.1925,
#               0.2673,
#               0.2774,
#               0.3333,
#               0.2425,
#               0.2774,
#               0.378,
#               0.2357],
#              'agenc': [0.2673,
#               0.2236,
#               0.2182,
#               0.2673,
#               0.2582,
#               0.2673,
#               0.2582,
#               0.2236,
#               0.2582,
#               0.2887,
#               0.2673,
#               0.3536,
#               0.2774,
#               0.25,
#               0.2425],
#              'coincid': [0.2673, 0.2774, 0.378],
#              'victori': [0.2673,
#               0.2582,
#               0.4082,
#               1.0,
#               0.5547,
#               0.3015,
#               0.2236,
#               0.2774,
#               0.4472,
#               0.5,
#               0.4082,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.378,
#               0.4472,
#               0.4472,
#               0.4472,
#               0.4082,
#               0.4082,
#               0.4082,
#               0.3015,
#               0.7071,
#               0.2357,
#               0.2357,
#               0.3536,
#               0.2774],
#              'shambol': [0.3333],
#              'tweet': [0.3333,
#               0.4082,
#               0.2236,
#               0.3536,
#               0.3162,
#               0.2182,
#               0.4082,
#               0.2236,
#               0.2887,
#               0.1961,
#               0.4472,
#               0.2425,
#               0.417],
#              '15pc': [0.3333],
#              'noahmurphynft': [0.2085],
#              'promot': [0.2085, 0.4472, 0.2887],
#              'nft': [0.2085],
#              'project': [0.2085, 0.2887, 0.3333, 0.2582, 0.3162],
#              'childen': [0.2085],
#              'women': [0.2085,
#               0.2582,
#               0.2085,
#               0.1601,
#               0.1796,
#               0.1961,
#               0.2887,
#               0.3162,
#               0.378,
#               0.2673,
#               0.2582,
#               0.1925,
#               0.2887,
#               0.3536],
#              'mean': [0.2085,
#               0.2182,
#               0.2236,
#               0.3015,
#               0.2182,
#               0.2182,
#               0.2182,
#               0.2774,
#               0.2357,
#               0.2236,
#               0.2294,
#               0.1826,
#               0.1925,
#               0.2774,
#               0.25,
#               0.378,
#               0.2357,
#               0.2357,
#               0.2132,
#               0.5774,
#               0.4082,
#               0.3015,
#               0.4082,
#               0.2182,
#               0.2132,
#               0.25,
#               0.2236,
#               0.2887,
#               0.2774,
#               0.2673,
#               0.25,
#               0.3333,
#               0.2182],
#              'lot': [0.2085,
#               0.3333,
#               0.189,
#               0.3015,
#               0.2085,
#               0.2357,
#               0.1925,
#               0.2182,
#               0.2182,
#               0.3536,
#               0.3536,
#               0.2425,
#               0.1741,
#               0.4472,
#               0.2582,
#               0.2041,
#               0.4472,
#               0.1925,
#               0.2294,
#               0.2294,
#               0.2887,
#               0.2236,
#               0.1741,
#               0.2],
#              'center': [0.2774,
#               0.1961,
#               0.2182,
#               0.2182,
#               0.2236,
#               0.25,
#               0.2294,
#               0.3536,
#               0.2357,
#               0.3333,
#               0.3162,
#               0.3015,
#               0.2041,
#               0.2294,
#               0.1741,
#               0.3333,
#               0.2357,
#               0.3333,
#               0.2887],
#              'sabotag': [0.2774,
#               0.25,
#               0.2774,
#               0.2236,
#               0.4472,
#               0.2582,
#               0.2132,
#               0.3536,
#               0.2582,
#               0.2357,
#               0.4472,
#               0.2357,
#               0.3162,
#               0.2673,
#               0.3162,
#               0.25,
#               0.2425,
#               0.2425,
#               0.3015,
#               0.3162,
#               0.4472,
#               0.5774,
#               0.5774,
#               0.2,
#               0.3015,
#               0.2294,
#               0.378,
#               0.1715,
#               0.2294,
#               0.2425,
#               0.2182,
#               0.6325,
#               0.3333,
#               0.2182,
#               0.2132,
#               0.3536,
#               0.2085,
#               0.3162,
#               0.3015,
#               0.2294,
#               0.2887,
#               0.378,
#               0.4082],
#              'fear': [0.2774,
#               0.2182,
#               0.3333,
#               0.3333,
#               0.3162,
#               0.1925,
#               0.2182,
#               0.3162,
#               0.3536,
#               0.2582,
#               0.3162,
#               0.3162,
#               0.4472,
#               0.3162,
#               0.3015,
#               0.2425,
#               0.2132],
#              'woke': [0.2774, 0.2582],
#              'alex': [0.2774, 0.2673],
#              'christofor': [0.2774, 0.2673],
#              'breakingrussia': [0.2],
#              'partli': [0.2, 0.2236],
#              ...})

# %% [markdown]
# Document Frequency measures how many documents in a corpus contain a specific term (word or phrase).

# %%
df
# Out:
# defaultdict(int,
#             {'melsimmonsfcdo': 1,
#              'wrong': 19,
#              'dictat': 9,
#              "putin'": 63,
#              'fascist': 9,
#              'russia': 502,
#              'intend': 5,
#              'conquer': 2,
#              'much': 28,
#              'ukrainian': 435,
#              'land': 63,
#              'possibl': 36,
#              'arm': 105,
#              'forc': 256,
#              'liber': 44,
#              'villag': 14,
#              'urban': 2,
#              'territori': 165,
#              'commun': 18,
#              'regionukrainerussiawar': 1,
#              'alert': 11,
#              'poland': 17,
#              'prep': 1,
#              'antiradi': 1,
#              'tablet': 1,
#              'nuclear': 99,
#              'threat': 39,
#              'im': 14,
#              'still': 35,
#              'wait': 19,
#              'googl': 2,
#              'map': 26,
#              'updat': 39,
#              'new': 149,
#              'annex': 215,
#              'take': 71,
#              'bit': 3,
#              'longer': 11,
#              'thought': 13,
#              'emmanuelmacron': 6,
#              'probabl': 14,
#              'right': 59,
#              'say': 111,
#              'anyway': 4,
#              'game': 12,
#              'citizen': 46,
#              'tire': 3,
#              'pay': 13,
#              'endless': 2,
#              'estonia': 5,
#              'lithuania': 8,
#              'latvia': 5,
#              'fulli': 6,
#              'support': 95,
#              'welcom': 21,
#              'ukrain': 832,
#              'nato': 133,
#              'soon': 28,
#              "lithuania'": 1,
#              'minist': 35,
#              'foreign': 39,
#              'affair': 6,
#              'poke': 1,
#              'bear': 2,
#              'get': 79,
#              'mad': 9,
#              'wake': 8,
#              'smell': 3,
#              'unsanitari': 1,
#              'chemic': 1,
#              'biolab': 2,
#              'condemn': 22,
#              "russia'": 47,
#              'illeg': 25,
#              'call': 83,
#              'russian': 817,
#              'feder': 42,
#              'withdraw': 6,
#              'across': 10,
#              'putin': 414,
#              'cheer': 5,
#              'crowd': 3,
#              'red': 12,
#              'yard': 1,
#              'moscow': 57,
#              'west': 72,
#              'dont': 28,
#              'recal': 1,
#              'peacetruc': 1,
#              'talk': 28,
#              'peopl': 187,
#              'win': 31,
#              'cannot': 13,
#              'obviou': 5,
#              'reason': 23,
#              'war': 416,
#              'countri': 90,
#              'join': 64,
#              'whilst': 1,
#              'would': 71,
#              'also': 52,
#              'trigger': 2,
#              'end': 75,
#              'day': 90,
#              'berlin': 4,
#              'brussel': 3,
#              'london': 4,
#              'stockholm': 1,
#              'pari': 2,
#              'europ': 62,
#              'like': 109,
#              'kyiv': 33,
#              'continent': 1,
#              "let'": 10,
#              'face': 32,
#              'took': 15,
#              '90': 5,
#              'thousand': 18,
#              'kilomet': 2,
#              '15': 8,
#              'percent': 2,
#              'area': 50,
#              'includ': 38,
#              'boundari': 2,
#              'men': 39,
#              'flee': 42,
#              'turkey': 4,
#              'avoid': 15,
#              'mobilis': 29,
#              'france24': 2,
#              'consul': 4,
#              'vandal': 2,
#              'nyc': 2,
#              'declar': 36,
#              'come': 58,
#              'presid': 85,
#              'four': 56,
#              'occupi': 123,
#              'watch': 40,
#              'video': 208,
#              '1½': 1,
#              'minut': 15,
#              'oper': 55,
#              'septemb': 87,
#              '2930': 1,
#              'align': 3,
#              'sourc': 24,
#              'rybar': 4,
#              'bomber': 4,
#              'capabl': 12,
#              'carri': 16,
#              'nuke': 23,
#              'detect': 8,
#              'near': 67,
#              'cruis': 2,
#              'missil': 112,
#              'strateg': 10,
#              'weapon': 91,
#              'ukrainewar': 65,
#              'ukrainerussiawar': 12,
#              'number': 20,
#              'kill': 106,
#              'result': 43,
#              'rocket': 32,
#              'attack': 115,
#              'humanitarian': 25,
#              'convoy': 39,
#              'increas': 27,
#              '30': 51,
#              'injur': 36,
#              '88': 3,
#              '27': 9,
#              'law': 17,
#              'enforc': 3,
#              'offic': 20,
#              'offici': 41,
#              'armi': 136,
#              'order': 38,
#              'soldier': 133,
#              'passport': 4,
#              'return': 32,
#              'immedi': 27,
#              'ukrainerussiawarrussian': 63,
#              'troop': 119,
#              'captur': 43,
#              'bmp2m': 3,
#              'ifv': 1,
#              'ongo': 11,
#              'offens': 34,
#              'oblast': 72,
#              'evil': 7,
#              'vladimir': 54,
#              'puppet': 7,
#              "europe'": 1,
#              'biggest': 9,
#              'grab': 8,
#              'sinc': 29,
#              'world': 130,
#              'ii': 7,
#              'hey': 8,
#              'thank': 30,
#              'put': 34,
#              'tu160': 1,
#              'easi': 7,
#              'reach': 13,
#              'f22': 1,
#              'could': 43,
#              'north': 16,
#              'norway': 6,
#              'finaldn': 1,
#              'via': 95,
#              'tanker': 2,
#              'thule': 1,
#              'brilliant': 4,
#              'strategist': 2,
#              'negoti': 37,
#              'long': 28,
#              'leader': 35,
#              'kremlinrussia_': 9,
#              'go': 99,
#              'fuck': 75,
#              'crimin': 19,
#              'thug': 1,
#              'know': 67,
#              'leav': 57,
#              'mass': 12,
#              'send': 46,
#              'death': 39,
#              'us': 187,
#              'alli': 19,
#              'afraid': 6,
#              'defend': 48,
#              'everi': 39,
#              'inch': 4,
#              'biden': 28,
#              'prepar': 31,
#              'singl': 6,
#              'recognis': 8,
#              'attempt': 14,
#              'continu': 50,
#              'provid': 17,
#              'secur': 40,
#              'assist': 15,
#              'demolish': 1,
#              'tank': 98,
#              'hous': 23,
#              'former': 8,
#              'prime': 3,
#              'mikhail': 1,
#              'kasyanov': 1,
#              'believ': 34,
#              'step': 12,
#              'posit': 37,
#              'month': 29,
#              'caitlin': 1,
#              'johnston': 1,
#              'risk': 10,
#              'upset': 2,
#              'entir': 19,
#              'internet': 5,
#              '4': 69,
#              'seem': 25,
#              'great': 17,
#              'time': 113,
#              'western': 32,
#              'nation': 46,
#              'dismiss': 3,
#              'referendum': 69,
#              'rt': 2,
#              'appreci': 2,
#              'tysm': 2,
#              'zine_app': 2,
#              'zinetown': 2,
#              'anizi': 2,
#              'faneventshub': 2,
#              'originalmerchrt': 2,
#              'zinesgod': 2,
#              'atozines_bot': 2,
#              'zzinethat': 2,
#              'allfandomev': 2,
#              'thewrittenvoid': 2,
#              'shrine_zin': 2,
#              'yoizin': 2,
#              'fanzinecentr': 2,
#              'look': 50,
#              'enthusiasm': 1,
#              'patriot': 3,
#              'exalt': 1,
#              'referendumshow': 1,
#              'gener': 48,
#              'among': 14,
#              'moskal': 1,
#              'elit': 7,
#              'mayb': 13,
#              'alreadi': 35,
#              'court': 3,
#              'rope': 2,
#              'gallow': 1,
#              'embassi': 10,
#              'air': 32,
#              'raid': 2,
#              'warn': 41,
#              'issu': 15,
#              'except': 4,
#              'human': 20,
#              'finest': 2,
#              'second': 13,
#              'half': 9,
#              'monument': 1,
#              'initi': 8,
#              'push': 26,
#              'although': 4,
#              'pace': 2,
#              'becam': 5,
#              'littl': 16,
#              'slower': 1,
#              'driven': 1,
#              'anoth': 49,
#              '40km': 1,
#              'realli': 32,
#              'help': 67,
#              'translat': 8,
#              'recent': 18,
#              'speech': 36,
#              'appli': 17,
#              'membership': 15,
#              'volodymyr': 17,
#              'ceremoni': 30,
#              'farc': 3,
#              'rule': 9,
#              "everyone'": 2,
#              'favorit': 1,
#              'someth': 13,
#              'big': 25,
#              'happen': 40,
#              'current': 24,
#              'airbas': 1,
#              'potenti': 8,
#              'develop': 6,
#              'consequ': 19,
#              'appear': 14,
#              'match': 6,
#              'rhetor': 2,
#              'night': 24,
#              'southern': 16,
#              'drone': 52,
#              '92km': 2,
#              'munit': 10,
#              'secretarygener': 3,
#              "stoltenberg'": 1,
#              'channel': 16,
#              'dwnew': 4,
#              'interrupt': 1,
#              'footag': 34,
#              'speak': 13,
#              'concert': 5,
#              'region': 242,
#              'reinforc': 4,
#              'repel': 8,
#              "ukraine'": 33,
#              'counterattack': 2,
#              'modern': 12,
#              'mstasm2': 1,
#              '152mm': 1,
#              'selfpropel': 7,
#              'howitz': 9,
#              'kharkiv': 38,
#              'defiant': 1,
#              'zelenskiy': 2,
#              'announc': 67,
#              'hour': 25,
#              'said': 67,
#              'kremlin': 37,
#              'provinc': 10,
#              'histor': 14,
#              'final': 10,
#              'referenda': 34,
#              'infuri': 1,
#              'collect': 3,
#              'duran': 2,
#              'mur': 15,
#              'lilek': 15,
#              'innifsek': 15,
#              'maltes': 15,
#              'recreat': 1,
#              'imag': 9,
#              'disord': 1,
#              'mind': 7,
#              'full': 24,
#              'violenc': 5,
#              'hatr': 2,
#              'instabl': 1,
#              'paranoia': 1,
#              'hate': 6,
#              'chao': 4,
#              'within': 16,
#              'beget': 1,
#              'without': 22,
#              'sign': 69,
#              'applic': 21,
#              'kherson': 91,
#              'zaporozhy': 29,
#              'becom': 29,
#              'forev': 11,
#              'ceas': 7,
#              'fire': 54,
#              'kiev': 7,
#              'start': 39,
#              'back': 58,
#              '2014': 11,
#              'lyman': 114,
#              'stalingrad': 2,
#              'never': 27,
#              'abl': 12,
#              'renam': 2,
#              'putingrad': 1,
#              'democraci': 11,
#              'tyranni': 3,
#              'denmark': 5,
#              'state': 139,
#              'sight': 3,
#              'mysteri': 8,
#              'seen': 21,
#              'oil': 8,
#              'amp': 181,
#              'ga': 47,
#              'field': 9,
#              'french': 3,
#              'don': 1,
#              'mask': 1,
#              'tradit': 3,
#              'battl': 34,
#              'flag': 12,
#              'color': 2,
#              'militari': 156,
#              'equip': 55,
#              'allegedli': 5,
#              'head': 58,
#              'crimea': 26,
#              'confirm': 7,
#              'rout': 9,
#              'control': 34,
#              'uav': 10,
#              'monitor': 4,
#              'beirut': 1,
#              'explos': 51,
#              'ua': 13,
#              'apu': 10,
#              'ruin': 5,
#              'special': 32,
#              'innoc': 6,
#              'price': 25,
#              'impos': 17,
#              'sanction': 46,
#              'joebiden': 3,
#              'zelenskyyua': 44,
#              'gone': 9,
#              'far': 19,
#              'way': 45,
#              'nightmar': 5,
#              'find': 22,
#              'replac': 5,
#              'next': 26,
#              'random': 1,
#              'decre': 23,
#              "'afterparty'": 1,
#              'civilian': 88,
#              'travel': 9,
#              'deliv': 10,
#              'aid': 36,
#              'hit': 76,
#              'strike': 73,
#              'left': 27,
#              'least': 19,
#              '25': 17,
#              'dead': 42,
#              'happi': 12,
#              'enthusiast': 1,
#              'bunch': 5,
#              'sent': 34,
#              'front': 61,
#              'line': 39,
#              'decent': 2,
#              'one': 123,
#              'move': 22,
#              'level': 15,
#              'keep': 30,
#              'outsid': 5,
#              'conflict': 39,
#              'suppli': 40,
#              'ballist': 6,
#              'agreement': 13,
#              'use': 129,
#              'retali': 8,
#              'give': 38,
#              'fodder': 11,
#              'unfortun': 4,
#              'empti': 3,
#              'word': 26,
#              'see': 53,
#              'mock': 1,
#              '02': 2,
#              'conspir': 1,
#              '100': 17,
#              '200': 6,
#              'pm': 10,
#              'edt': 1,
#              'ill': 4,
#              'alisyncamerota': 1,
#              'cnn': 18,
#              'cnnnewsroom': 2,
#              'discuss': 13,
#              'latest': 17,
#              'news': 78,
#              'around': 31,
#              '225': 1,
#              'tri': 43,
#              'beat': 6,
#              'turn': 25,
#              'make': 80,
#              'fool': 12,
#              'conscript': 28,
#              'behav': 4,
#              'dombasal': 1,
#              'fairukrainerussiawar': 1,
#              'oppress': 2,
#              'glad': 2,
#              'heroic': 6,
#              'home': 32,
#              'brother': 9,
#              'sister': 4,
#              'pleas': 19,
#              'mr': 12,
#              'jensstoltenberg': 6,
#              'remov': 7,
#              'obstacl': 1,
#              'bureaucraci': 2,
#              'admiss': 3,
#              'need': 74,
#              'urgenc': 2,
#              'nsfw': 1,
#              'freshli': 1,
#              'releas': 10,
#              'mariupol': 6,
#              'mykola': 2,
#              'frostovik': 1,
#              'kushch': 1,
#              'member': 18,
#              'azov': 5,
#              'battalion': 5,
#              'sentenc': 1,
#              'confid': 4,
#              'wont': 9,
#              'fight': 84,
#              'die': 54,
#              'iran': 11,
#              'hold': 28,
#              'krasni': 6,
#              'liman': 9,
#              'town': 13,
#              'depend': 3,
#              'destroy': 114,
#              'pipelin': 59,
#              'middl': 6,
#              'east': 19,
#              'america': 10,
#              'claim': 32,
#              'eu': 43,
#              'close': 26,
#              'eye': 7,
#              'pictur': 8,
#              'everyth': 26,
#              'bomb': 40,
#              'pulp': 1,
#              'everyon': 30,
#              'love': 17,
#              'either': 5,
#              'fled': 12,
#              'tortur': 12,
#              'moment': 29,
#              'last': 39,
#              'feel': 20,
#              'want': 74,
#              'editori': 1,
#              'absolut': 12,
#              'actual': 17,
#              'meet': 23,
#              'treati': 4,
#              'oblig': 3,
#              'chang': 26,
#              'view': 15,
#              'accept': 18,
#              'directli': 5,
#              'enemi': 32,
#              'difficult': 3,
#              'situat': 29,
#              'sputnik': 1,
#              'report': 108,
#              'yesterday': 7,
#              '80': 6,
#              'mercenari': 14,
#              'execut': 8,
#              '1': 52,
#              'batteri': 2,
#              'finland': 18,
#              'readi': 27,
#              'differ': 17,
#              'zelenski': 35,
#              'formal': 14,
#              'ask': 27,
#              'gb': 1,
#              'japan': 4,
#              'fact': 11,
#              'remain': 24,
#              'place': 25,
#              'got': 19,
#              'togeth': 30,
#              'document': 15,
#              'legal': 11,
#              '3': 39,
#              'told': 17,
#              'lost': 22,
#              'clearli': 7,
#              '98': 2,
#              'anyon': 11,
#              'administr': 17,
#              'vet': 1,
#              'keen': 2,
#              'm30a1': 2,
#              'himar': 53,
#              'hot': 4,
#              'first': 37,
#              '81st': 1,
#              'airmobil': 1,
#              'brigad': 22,
#              'drobyshev': 9,
#              'think': 59,
#              'eu_commiss': 22,
#              'et': 2,
#              'al': 2,
#              'n': 30,
#              'assess': 7,
#              'slow': 3,
#              'gate': 4,
#              'defenceu': 19,
#              'lethal': 2,
#              'elimin': 10,
#              'mortar': 3,
#              'crew': 12,
#              'terrorist': 69,
#              'misunderstand': 2,
#              'potu': 32,
#              'charlestannock': 1,
#              'samramani2': 3,
#              'apmassaro3': 6,
#              'zeitonlin': 1,
#              'acceler': 15,
#              'reject': 7,
#              'submit': 10,
#              'expand': 5,
#              'jacksonhinkl': 1,
#              'good': 50,
#              'morn': 27,
#              'h604': 1,
#              'chief': 10,
#              'action': 26,
#              "'seriou": 1,
#              "escalation'": 2,
#              'request': 12,
#              'post': 35,
#              'global': 20,
#              'voic': 28,
#              "today'": 6,
#              'colon': 3,
#              'cut': 23,
#              'popul': 20,
#              '60': 12,
#              'prosper': 2,
#              'form': 14,
#              'break': 46,
#              'semicircl': 1,
#              'afu': 19,
#              'usambun': 1,
#              'antonioguterr': 5,
#              'best': 17,
#              'thing': 31,
#              'wouldnt': 5,
#              'better': 12,
#              'follow': 50,
#              'peac': 70,
#              'instead': 11,
#              'rock': 4,
#              'boat': 2,
#              'simpli': 9,
#              'worth': 7,
#              'escal': 32,
#              'strife': 1,
#              'odd': 4,
#              'doesnt': 3,
#              'trap': 10,
#              'hell': 13,
#              'moskovit': 1,
#              'occup': 14,
#              'conduct': 4,
#              'experi': 2,
#              'pretend': 1,
#              'nobl': 1,
#              'goal': 9,
#              'six': 1,
#              'command': 27,
#              'master': 7,
#              'thread': 64,
#              'evolv': 3,
#              'fallout': 1,
#              'nord': 39,
#              'stream': 45,
#              'conor': 1,
#              'gallagherseptemb': 1,
#              '2022': 90,
#              'gallagh': 1,
#              'encircl': 48,
#              'seriou': 9,
#              'setback': 2,
#              'largest': 7,
#              'citi': 66,
#              'earli': 5,
#              'invas': 61,
#              'src': 1,
#              'thestudyofwar': 8,
#              'nytgraph': 1,
#              'european': 33,
#              'extern': 1,
#              'servic': 21,
#              'independ': 30,
#              'cc': 2,
#              'josepborrellf': 3,
#              'huge': 11,
#              'swath': 3,
#              "there'": 8,
#              'real': 25,
#              'nazi': 20,
#              'bloodi': 3,
#              'z_game': 1,
#              'trust': 8,
#              'god': 11,
#              'trial': 3,
#              'life': 25,
#              'amaz': 4,
#              'parent': 2,
#              'afford': 1,
#              '8m': 1,
#              'car': 22,
#              'atlant': 2,
#              'council': 24,
#              'denounc': 7,
#              'imperi': 5,
#              'larg': 14,
#              'saldo': 1,
#              'ruspuppet': 1,
#              'today': 63,
#              'settlement': 11,
#              'mykolaiv': 14,
#              'den_2042': 1,
#              'strang': 6,
#              'show': 57,
#              'reflect': 2,
#              'battlefield': 13,
#              'mobil': 104,
#              'loss': 23,
#              'disconnect': 1,
#              'realiti': 7,
#              'regim': 15,
#              'germani': 30,
#              'weird': 5,
#              "we'r": 5,
#              'danger': 14,
#              'ball': 5,
#              'american': 36,
#              'hypocrisi': 3,
#              'taiwan': 3,
#              'persecut': 2,
#              'ethnic': 12,
#              'shell': 50,
#              'deserv': 5,
#              'top10ap': 1,
#              'columbiabugl': 1,
#              'correctiona': 1,
#              'fledg': 1,
#              'invad': 31,
#              'corrupt': 7,
#              'aggress': 17,
#              'power': 44,
#              'baltic': 12,
#              'friend': 12,
#              'urma': 2,
#              'reinsalu': 2,
#              'republ': 18,
#              'ukraine_world': 2,
#              'let': 43,
#              'interpret': 2,
#              "biden'": 2,
#              'respons': 38,
#              'usnato': 3,
#              'jam': 1,
#              'suffer': 17,
#              'damag': 28,
#              'agre': 11,
#              'fate': 5,
#              'confront': 4,
#              'decid': 10,
#              'firm': 5,
#              'border': 49,
#              'short': 8,
#              'clip': 4,
#              'uran6': 4,
#              'mine': 11,
#              'clear': 14,
#              'robot': 3,
#              'goe': 11,
#              'met': 5,
#              'beneath': 1,
#              'audio': 4,
#              'top': 5,
#              'prioriti': 6,
#              'nowukrainerussiawar': 1,
#              'defens': 57,
#              'individu': 3,
#              'entiti': 5,
#              'unilater': 1,
#              'rare': 5,
#              'work': 51,
#              '70': 4,
#              'mlr': 9,
#              'system': 40,
#              'planet': 4,
#              'york': 10,
#              '15m': 2,
#              'subject': 8,
#              'robthomas14': 1,
#              'bordernick1': 1,
#              'jacothenorth': 1,
#              'notic': 5,
#              'phoney': 1,
#              'robert': 2,
#              'virtuesignal': 1,
#              "anywayhere'": 1,
#              'itppl': 1,
#              'meantim': 3,
#              'stole': 1,
#              'even': 40,
#              'idea': 6,
#              'uniform': 5,
#              'movi': 3,
#              'wave': 3,
#              'well': 41,
#              'anxiou': 2,
#              'angri': 3,
#              'tear': 4,
#              "kadyrov'": 1,
#              'silenc': 5,
#              'memori': 5,
#              'donbass': 14,
#              'tension': 5,
#              'greet': 1,
#              'gift': 1,
#              'stabil': 3,
#              'authoritarian': 1,
#              'endlessli': 1,
#              'inflict': 6,
#              'upon': 4,
#              'prison': 15,
#              'stop': 50,
#              'genevasummit': 1,
#              'alum': 1,
#              'navalni': 2,
#              'poignantli': 1,
#              'opinion': 11,
#              'read': 29,
#              'ope': 2,
#              'maria': 1,
#              'zakharova': 1,
#              'specul': 1,
#              'must': 71,
#              'admit': 6,
#              'unit': 93,
#              'spoke': 1,
#              'promis': 4,
#              '2': 65,
#              'amnesti': 2,
#              'intern': 22,
#              'zaporizhzhia': 55,
#              'proof': 4,
#              'utter': 1,
#              'disregard': 1,
#              'live': 53,
#              'clash': 1,
#              'u': 8,
#              'rat': 5,
#              'rape': 3,
#              'begir': 1,
#              'summer': 3,
#              '23': 26,
#              'manhattan': 1,
#              'ride': 1,
#              'freedom': 8,
#              'financi': 6,
#              'caus': 21,
#              'pocket': 6,
#              'saw': 4,
#              'caribean': 1,
#              'tax': 5,
#              'heaven': 2,
#              'secret': 9,
#              'account': 9,
#              'expos': 5,
#              'pandora': 2,
#              'paper': 11,
#              'ampnato': 1,
#              'sold': 3,
#              '3rd': 2,
#              'countriesukrain': 1,
#              'guard': 16,
#              'spot': 5,
#              'two': 52,
#              'silhouett': 1,
#              'shape': 2,
#              'behind': 18,
#              'wild': 2,
#              'boar': 1,
#              'moldova': 1,
#              'young': 16,
#              'draft': 26,
#              'age': 13,
#              'getaway': 1,
#              'deni': 8,
#              'blast': 6,
#              'outright': 1,
#              'satan': 2,
#              'secretari': 24,
#              'retak': 6,
#              'blackmail': 4,
#              'convey': 3,
#              'ite': 11,
#              'pedicabo': 11,
#              'te': 11,
#              'ipsum': 11,
#              'latin': 11,
#              'friday': 22,
#              'sever': 23,
#              'joe': 11,
#              "moscow'": 3,
#              'fraudul': 2,
#              'run': 29,
#              'beschlossdc': 1,
#              'sitdown': 1,
#              'jordanbpeterson': 1,
#              'media': 30,
#              'celebr': 12,
#              'seek': 7,
#              'offer': 10,
#              'excus': 2,
#              'scum': 4,
#              'unequivoc': 5,
#              'shout': 2,
#              'gangster': 1,
#              'bulli': 5,
#              'teenag': 1,
#              'postannex': 1,
#              'neighborhood': 2,
#              'tragic': 3,
#              'whistl': 1,
#              'walk': 4,
#              'cemeteri': 1,
#              'bad': 9,
#              'await': 2,
#              'awar': 2,
#              'livabl': 1,
#              'stoltenberg': 10,
#              'agenc': 15,
#              'coincid': 3,
#              'victori': 33,
#              'shambol': 1,
#              'tweet': 13,
#              '15pc': 1,
#              'noahmurphynft': 1,
#              'promot': 3,
#              'nft': 1,
#              'project': 5,
#              'childen': 1,
#              'women': 14,
#              'mean': 33,
#              'lot': 24,
#              'center': 19,
#              'sabotag': 43,
#              'fear': 17,
#              'woke': 2,
#              'alex': 2,
#              'christofor': 2,
#              'breakingrussia': 1,
#              'partli': 2,
#              ...})

# %% [markdown]
# Inverse Document Frequency measures the importance of a term across a collection of documents (corpus).

# %%
idf
# Out:
# defaultdict(float,
#             {'melsimmonsfcdo': 8.294,
#              'wrong': 5.3496,
#              'dictat': 6.0968,
#              "putin'": 4.1509,
#              'fascist': 6.0968,
#              'russia': 2.0754,
#              'intend': 6.6846,
#              'conquer': 7.6009,
#              'much': 4.9618,
#              'ukrainian': 2.2187,
#              'land': 4.1509,
#              'possibl': 4.7105,
#              'arm': 3.6401,
#              'forc': 2.7489,
#              'liber': 4.5099,
#              'villag': 5.655,
#              'urban': 7.6009,
#              'territori': 3.1881,
#              'commun': 5.4037,
#              'regionukrainerussiawar': 8.294,
#              'alert': 5.8962,
#              'poland': 5.4608,
#              'prep': 8.294,
#              'antiradi': 8.294,
#              'tablet': 8.294,
#              'nuclear': 3.6989,
#              'threat': 4.6305,
#              'im': 5.655,
#              'still': 4.7387,
#              'wait': 5.3496,
#              'googl': 7.6009,
#              'map': 5.036,
#              'updat': 4.6305,
#              'new': 3.2901,
#              'annex': 2.9234,
#              'take': 4.0314,
#              'bit': 7.1954,
#              'longer': 5.8962,
#              'thought': 5.7291,
#              'emmanuelmacron': 6.5023,
#              'probabl': 5.655,
#              'right': 4.2165,
#              'say': 3.5845,
#              'anyway': 6.9078,
#              'game': 5.8091,
#              'citizen': 4.4654,
#              'tire': 7.1954,
#              'pay': 5.7291,
#              'endless': 7.6009,
#              'estonia': 6.6846,
#              'lithuania': 6.2146,
#              'latvia': 6.6846,
#              'fulli': 6.5023,
#              'support': 3.7402,
#              'welcom': 5.2495,
#              'ukrain': 1.5702,
#              'nato': 3.4037,
#              'soon': 4.9618,
#              "lithuania'": 8.294,
#              'minist': 4.7387,
#              'foreign': 4.6305,
#              'affair': 6.5023,
#              'poke': 8.294,
#              'bear': 7.6009,
#              'get': 3.9246,
#              'mad': 6.0968,
#              'wake': 6.2146,
#              'smell': 7.1954,
#              'unsanitari': 8.294,
#              'chemic': 8.294,
#              'biolab': 7.6009,
#              'condemn': 5.203,
#              "russia'": 4.4439,
#              'illeg': 5.0752,
#              'call': 3.8752,
#              'russian': 1.5884,
#              'feder': 4.5564,
#              'withdraw': 6.5023,
#              'across': 5.9915,
#              'putin': 2.2682,
#              'cheer': 6.6846,
#              'crowd': 7.1954,
#              'red': 5.8091,
#              'yard': 8.294,
#              'moscow': 4.251,
#              'west': 4.0174,
#              'dont': 4.9618,
#              'recal': 8.294,
#              'peacetruc': 8.294,
#              'talk': 4.9618,
#              'peopl': 3.0629,
#              'win': 4.8601,
#              'cannot': 5.7291,
#              'obviou': 6.6846,
#              'reason': 5.1586,
#              'war': 2.2634,
#              'countri': 3.7942,
#              'join': 4.1352,
#              'whilst': 8.294,
#              'would': 4.0314,
#              'also': 4.3428,
#              'trigger': 7.6009,
#              'end': 3.9766,
#              'day': 3.7942,
#              'berlin': 6.9078,
#              'brussel': 7.1954,
#              'london': 6.9078,
#              'stockholm': 8.294,
#              'pari': 7.6009,
#              'europ': 4.1669,
#              'like': 3.6027,
#              'kyiv': 4.7975,
#              'continent': 8.294,
#              "let'": 5.9915,
#              'face': 4.8283,
#              'took': 5.586,
#              '90': 6.6846,
#              'thousand': 5.4037,
#              'kilomet': 7.6009,
#              '15': 6.2146,
#              'percent': 7.6009,
#              'area': 4.382,
#              'includ': 4.6565,
#              'boundari': 7.6009,
#              'men': 4.6305,
#              'flee': 4.5564,
#              'turkey': 6.9078,
#              'avoid': 5.586,
#              'mobilis': 4.9268,
#              'france24': 7.6009,
#              'consul': 6.9078,
#              'vandal': 7.6009,
#              'nyc': 7.6009,
#              'declar': 4.7105,
#              'come': 4.2336,
#              'presid': 3.8514,
#              'four': 4.2687,
#              'occupi': 3.4819,
#              'watch': 4.6052,
#              'video': 2.9565,
#              '1½': 8.294,
#              'minut': 5.586,
#              'oper': 4.2867,
#              'septemb': 3.8281,
#              '2930': 8.294,
#              'align': 7.1954,
#              'sourc': 5.116,
#              'rybar': 6.9078,
#              'bomber': 6.9078,
#              'capabl': 5.8091,
#              'carri': 5.5215,
#              'nuke': 5.1586,
#              'detect': 6.2146,
#              'near': 4.0894,
#              'cruis': 7.6009,
#              'missil': 3.5756,
#              'strateg': 5.9915,
#              'weapon': 3.7832,
#              'ukrainewar': 4.1197,
#              'ukrainerussiawar': 5.8091,
#              'number': 5.2983,
#              'kill': 3.6306,
#              'result': 4.5328,
#              'rocket': 4.8283,
#              'attack': 3.5491,
#              'humanitarian': 5.0752,
#              'convoy': 4.6305,
#              'increas': 4.9982,
#              '30': 4.3622,
#              'injur': 4.7105,
#              '88': 7.1954,
#              '27': 6.0968,
#              'law': 5.4608,
#              'enforc': 7.1954,
#              'offic': 5.2983,
#              'offici': 4.5805,
#              'armi': 3.3814,
#              'order': 4.6565,
#              'soldier': 3.4037,
#              'passport': 6.9078,
#              'return': 4.8283,
#              'immedi': 4.9982,
#              'ukrainerussiawarrussian': 4.1509,
#              'troop': 3.5149,
#              'captur': 4.5328,
#              'bmp2m': 7.1954,
#              'ifv': 8.294,
#              'ongo': 5.8962,
#              'offens': 4.7677,
#              'oblast': 4.0174,
#              'evil': 6.3481,
#              'vladimir': 4.3051,
#              'puppet': 6.3481,
#              "europe'": 8.294,
#              'biggest': 6.0968,
#              'grab': 6.2146,
#              'sinc': 4.9268,
#              'world': 3.4265,
#              'ii': 6.3481,
#              'hey': 6.2146,
#              'thank': 4.8929,
#              'put': 4.7677,
#              'tu160': 8.294,
#              'easi': 6.3481,
#              'reach': 5.7291,
#              'f22': 8.294,
#              'could': 4.5328,
#              'north': 5.5215,
#              'norway': 6.5023,
#              'finaldn': 8.294,
#              'via': 3.7402,
#              'tanker': 7.6009,
#              'thule': 8.294,
#              'brilliant': 6.9078,
#              'strategist': 7.6009,
#              'negoti': 4.6831,
#              'long': 4.9618,
#              'leader': 4.7387,
#              'kremlinrussia_': 6.0968,
#              'go': 3.6989,
#              'fuck': 3.9766,
#              'crimin': 5.3496,
#              'thug': 8.294,
#              'know': 4.0894,
#              'leav': 4.251,
#              'mass': 5.8091,
#              'send': 4.4654,
#              'death': 4.6305,
#              'us': 3.0629,
#              'alli': 5.3496,
#              'afraid': 6.5023,
#              'defend': 4.4228,
#              'everi': 4.6305,
#              'inch': 6.9078,
#              'biden': 4.9618,
#              'prepar': 4.8601,
#              'singl': 6.5023,
#              'recognis': 6.2146,
#              'attempt': 5.655,
#              'continu': 4.382,
#              'provid': 5.4608,
#              'secur': 4.6052,
#              'assist': 5.586,
#              'demolish': 8.294,
#              'tank': 3.7091,
#              'hous': 5.1586,
#              'former': 6.2146,
#              'prime': 7.1954,
#              'mikhail': 8.294,
#              'kasyanov': 8.294,
#              'believ': 4.7677,
#              'step': 5.8091,
#              'posit': 4.6831,
#              'month': 4.9268,
#              'caitlin': 8.294,
#              'johnston': 8.294,
#              'risk': 5.9915,
#              'upset': 7.6009,
#              'entir': 5.3496,
#              'internet': 6.6846,
#              '4': 4.0599,
#              'seem': 5.0752,
#              'great': 5.4608,
#              'time': 3.5667,
#              'western': 4.8283,
#              'nation': 4.4654,
#              'dismiss': 7.1954,
#              'referendum': 4.0599,
#              'rt': 7.6009,
#              'appreci': 7.6009,
#              'tysm': 7.6009,
#              'zine_app': 7.6009,
#              'zinetown': 7.6009,
#              'anizi': 7.6009,
#              'faneventshub': 7.6009,
#              'originalmerchrt': 7.6009,
#              'zinesgod': 7.6009,
#              'atozines_bot': 7.6009,
#              'zzinethat': 7.6009,
#              'allfandomev': 7.6009,
#              'thewrittenvoid': 7.6009,
#              'shrine_zin': 7.6009,
#              'yoizin': 7.6009,
#              'fanzinecentr': 7.6009,
#              'look': 4.382,
#              'enthusiasm': 8.294,
#              'patriot': 7.1954,
#              'exalt': 8.294,
#              'referendumshow': 8.294,
#              'gener': 4.4228,
#              'among': 5.655,
#              'moskal': 8.294,
#              'elit': 6.3481,
#              'mayb': 5.7291,
#              'alreadi': 4.7387,
#              'court': 7.1954,
#              'rope': 7.6009,
#              'gallow': 8.294,
#              'embassi': 5.9915,
#              'air': 4.8283,
#              'raid': 7.6009,
#              'warn': 4.5805,
#              'issu': 5.586,
#              'except': 6.9078,
#              'human': 5.2983,
#              'finest': 7.6009,
#              'second': 5.7291,
#              'half': 6.0968,
#              'monument': 8.294,
#              'initi': 6.2146,
#              'push': 5.036,
#              'although': 6.9078,
#              'pace': 7.6009,
#              'becam': 6.6846,
#              'littl': 5.5215,
#              'slower': 8.294,
#              'driven': 8.294,
#              'anoth': 4.4022,
#              '40km': 8.294,
#              'realli': 4.8283,
#              'help': 4.0894,
#              'translat': 6.2146,
#              'recent': 5.4037,
#              'speech': 4.7105,
#              'appli': 5.4608,
#              'membership': 5.586,
#              'volodymyr': 5.4608,
#              'ceremoni': 4.8929,
#              'farc': 7.1954,
#              'rule': 6.0968,
#              "everyone'": 7.6009,
#              'favorit': 8.294,
#              'someth': 5.7291,
#              'big': 5.0752,
#              'happen': 4.6052,
#              'current': 5.116,
#              'airbas': 8.294,
#              'potenti': 6.2146,
#              'develop': 6.5023,
#              'consequ': 5.3496,
#              'appear': 5.655,
#              'match': 6.5023,
#              'rhetor': 7.6009,
#              'night': 5.116,
#              'southern': 5.5215,
#              'drone': 4.3428,
#              '92km': 7.6009,
#              'munit': 5.9915,
#              'secretarygener': 7.1954,
#              "stoltenberg'": 8.294,
#              'channel': 5.5215,
#              'dwnew': 6.9078,
#              'interrupt': 8.294,
#              'footag': 4.7677,
#              'speak': 5.7291,
#              'concert': 6.6846,
#              'region': 2.8051,
#              'reinforc': 6.9078,
#              'repel': 6.2146,
#              "ukraine'": 4.7975,
#              'counterattack': 7.6009,
#              'modern': 5.8091,
#              'mstasm2': 8.294,
#              '152mm': 8.294,
#              'selfpropel': 6.3481,
#              'howitz': 6.0968,
#              'kharkiv': 4.6565,
#              'defiant': 8.294,
#              'zelenskiy': 7.6009,
#              'announc': 4.0894,
#              'hour': 5.0752,
#              'said': 4.0894,
#              'kremlin': 4.6831,
#              'provinc': 5.9915,
#              'histor': 5.655,
#              'final': 5.9915,
#              'referenda': 4.7677,
#              'infuri': 8.294,
#              'collect': 7.1954,
#              'duran': 7.6009,
#              'mur': 5.586,
#              'lilek': 5.586,
#              'innifsek': 5.586,
#              'maltes': 5.586,
#              'recreat': 8.294,
#              'imag': 6.0968,
#              'disord': 8.294,
#              'mind': 6.3481,
#              'full': 5.116,
#              'violenc': 6.6846,
#              'hatr': 7.6009,
#              'instabl': 8.294,
#              'paranoia': 8.294,
#              'hate': 6.5023,
#              'chao': 6.9078,
#              'within': 5.5215,
#              'beget': 8.294,
#              'without': 5.203,
#              'sign': 4.0599,
#              'applic': 5.2495,
#              'kherson': 3.7832,
#              'zaporozhy': 4.9268,
#              'becom': 4.9268,
#              'forev': 5.8962,
#              'ceas': 6.3481,
#              'fire': 4.3051,
#              'kiev': 6.3481,
#              'start': 4.6305,
#              'back': 4.2336,
#              '2014': 5.8962,
#              'lyman': 3.5579,
#              'stalingrad': 7.6009,
#              'never': 4.9982,
#              'abl': 5.8091,
#              'renam': 7.6009,
#              'putingrad': 8.294,
#              'democraci': 5.8962,
#              'tyranni': 7.1954,
#              'denmark': 6.6846,
#              'state': 3.3596,
#              'sight': 7.1954,
#              'mysteri': 6.2146,
#              'seen': 5.2495,
#              'oil': 6.2146,
#              'amp': 3.0956,
#              'ga': 4.4439,
#              'field': 6.0968,
#              'french': 7.1954,
#              'don': 8.294,
#              'mask': 8.294,
#              'tradit': 7.1954,
#              'battl': 4.7677,
#              'flag': 5.8091,
#              'color': 7.6009,
#              'militari': 3.2442,
#              'equip': 4.2867,
#              'allegedli': 6.6846,
#              'head': 4.2336,
#              'crimea': 5.036,
#              'confirm': 6.3481,
#              'rout': 6.0968,
#              'control': 4.7677,
#              'uav': 5.9915,
#              'monitor': 6.9078,
#              'beirut': 8.294,
#              'explos': 4.3622,
#              'ua': 5.7291,
#              'apu': 5.9915,
#              'ruin': 6.6846,
#              'special': 4.8283,
#              'innoc': 6.5023,
#              'price': 5.0752,
#              'impos': 5.4608,
#              'sanction': 4.4654,
#              'joebiden': 7.1954,
#              'zelenskyyua': 4.5099,
#              'gone': 6.0968,
#              'far': 5.3496,
#              'way': 4.4874,
#              'nightmar': 6.6846,
#              'find': 5.203,
#              'replac': 6.6846,
#              'next': 5.036,
#              'random': 8.294,
#              'decre': 5.1586,
#              "'afterparty'": 8.294,
#              'civilian': 3.8167,
#              'travel': 6.0968,
#              'deliv': 5.9915,
#              'aid': 4.7105,
#              'hit': 3.9633,
#              'strike': 4.0036,
#              'left': 4.9982,
#              'least': 5.3496,
#              '25': 5.4608,
#              'dead': 4.5564,
#              'happi': 5.8091,
#              'enthusiast': 8.294,
#              'bunch': 6.6846,
#              'sent': 4.7677,
#              'front': 4.1832,
#              'line': 4.6305,
#              'decent': 7.6009,
#              'one': 3.4819,
#              'move': 5.203,
#              'level': 5.586,
#              'keep': 4.8929,
#              'outsid': 6.6846,
#              'conflict': 4.6305,
#              'suppli': 4.6052,
#              'ballist': 6.5023,
#              'agreement': 5.7291,
#              'use': 3.4342,
#              'retali': 6.2146,
#              'give': 4.6565,
#              'fodder': 5.8962,
#              'unfortun': 6.9078,
#              'empti': 7.1954,
#              'word': 5.036,
#              'see': 4.3238,
#              'mock': 8.294,
#              '02': 7.6009,
#              'conspir': 8.294,
#              '100': 5.4608,
#              '200': 6.5023,
#              'pm': 5.9915,
#              'edt': 8.294,
#              'ill': 6.9078,
#              'alisyncamerota': 8.294,
#              'cnn': 5.4037,
#              'cnnnewsroom': 7.6009,
#              'discuss': 5.7291,
#              'latest': 5.4608,
#              'news': 3.9373,
#              'around': 4.8601,
#              '225': 8.294,
#              'tri': 4.5328,
#              'beat': 6.5023,
#              'turn': 5.0752,
#              'make': 3.912,
#              'fool': 5.8091,
#              'conscript': 4.9618,
#              'behav': 6.9078,
#              'dombasal': 8.294,
#              'fairukrainerussiawar': 8.294,
#              'oppress': 7.6009,
#              'glad': 7.6009,
#              'heroic': 6.5023,
#              'home': 4.8283,
#              'brother': 6.0968,
#              'sister': 6.9078,
#              'pleas': 5.3496,
#              'mr': 5.8091,
#              'jensstoltenberg': 6.5023,
#              'remov': 6.3481,
#              'obstacl': 8.294,
#              'bureaucraci': 7.6009,
#              'admiss': 7.1954,
#              'need': 3.99,
#              'urgenc': 7.6009,
#              'nsfw': 8.294,
#              'freshli': 8.294,
#              'releas': 5.9915,
#              'mariupol': 6.5023,
#              'mykola': 7.6009,
#              'frostovik': 8.294,
#              'kushch': 8.294,
#              'member': 5.4037,
#              'azov': 6.6846,
#              'battalion': 6.6846,
#              'sentenc': 8.294,
#              'confid': 6.9078,
#              'wont': 6.0968,
#              'fight': 3.8632,
#              'die': 4.3051,
#              'iran': 5.8962,
#              'hold': 4.9618,
#              'krasni': 6.5023,
#              'liman': 6.0968,
#              'town': 5.7291,
#              'depend': 7.1954,
#              'destroy': 3.5579,
#              'pipelin': 4.2165,
#              'middl': 6.5023,
#              'east': 5.3496,
#              'america': 5.9915,
#              'claim': 4.8283,
#              'eu': 4.5328,
#              'close': 5.036,
#              'eye': 6.3481,
#              'pictur': 6.2146,
#              'everyth': 5.036,
#              'bomb': 4.6052,
#              'pulp': 8.294,
#              'everyon': 4.8929,
#              'love': 5.4608,
#              'either': 6.6846,
#              'fled': 5.8091,
#              'tortur': 5.8091,
#              'moment': 4.9268,
#              'last': 4.6305,
#              'feel': 5.2983,
#              'want': 3.99,
#              'editori': 8.294,
#              'absolut': 5.8091,
#              'actual': 5.4608,
#              'meet': 5.1586,
#              'treati': 6.9078,
#              'oblig': 7.1954,
#              'chang': 5.036,
#              'view': 5.586,
#              'accept': 5.4037,
#              'directli': 6.6846,
#              'enemi': 4.8283,
#              'difficult': 7.1954,
#              'situat': 4.9268,
#              'sputnik': 8.294,
#              'report': 3.6119,
#              'yesterday': 6.3481,
#              '80': 6.5023,
#              'mercenari': 5.655,
#              'execut': 6.2146,
#              '1': 4.3428,
#              'batteri': 7.6009,
#              'finland': 5.4037,
#              'readi': 4.9982,
#              'differ': 5.4608,
#              'zelenski': 4.7387,
#              'formal': 5.655,
#              'ask': 4.9982,
#              'gb': 8.294,
#              'japan': 6.9078,
#              'fact': 5.8962,
#              'remain': 5.116,
#              'place': 5.0752,
#              'got': 5.3496,
#              'togeth': 4.8929,
#              'document': 5.586,
#              'legal': 5.8962,
#              '3': 4.6305,
#              'told': 5.4608,
#              'lost': 5.203,
#              'clearli': 6.3481,
#              '98': 7.6009,
#              'anyon': 5.8962,
#              'administr': 5.4608,
#              'vet': 8.294,
#              'keen': 7.6009,
#              'm30a1': 7.6009,
#              'himar': 4.3238,
#              'hot': 6.9078,
#              'first': 4.6831,
#              '81st': 8.294,
#              'airmobil': 8.294,
#              'brigad': 5.203,
#              'drobyshev': 6.0968,
#              'think': 4.2165,
#              'eu_commiss': 5.203,
#              'et': 7.6009,
#              'al': 7.6009,
#              'n': 4.8929,
#              'assess': 6.3481,
#              'slow': 7.1954,
#              'gate': 6.9078,
#              'defenceu': 5.3496,
#              'lethal': 7.6009,
#              'elimin': 5.9915,
#              'mortar': 7.1954,
#              'crew': 5.8091,
#              'terrorist': 4.0599,
#              'misunderstand': 7.6009,
#              'potu': 4.8283,
#              'charlestannock': 8.294,
#              'samramani2': 7.1954,
#              'apmassaro3': 6.5023,
#              'zeitonlin': 8.294,
#              'acceler': 5.586,
#              'reject': 6.3481,
#              'submit': 5.9915,
#              'expand': 6.6846,
#              'jacksonhinkl': 8.294,
#              'good': 4.382,
#              'morn': 4.9982,
#              'h604': 8.294,
#              'chief': 5.9915,
#              'action': 5.036,
#              "'seriou": 8.294,
#              "escalation'": 7.6009,
#              'request': 5.8091,
#              'post': 4.7387,
#              'global': 5.2983,
#              'voic': 4.9618,
#              "today'": 6.5023,
#              'colon': 7.1954,
#              'cut': 5.1586,
#              'popul': 5.2983,
#              '60': 5.8091,
#              'prosper': 7.6009,
#              'form': 5.655,
#              'break': 4.4654,
#              'semicircl': 8.294,
#              'afu': 5.3496,
#              'usambun': 8.294,
#              'antonioguterr': 6.6846,
#              'best': 5.4608,
#              'thing': 4.8601,
#              'wouldnt': 6.6846,
#              'better': 5.8091,
#              'follow': 4.382,
#              'peac': 4.0456,
#              'instead': 5.8962,
#              'rock': 6.9078,
#              'boat': 7.6009,
#              'simpli': 6.0968,
#              'worth': 6.3481,
#              'escal': 4.8283,
#              'strife': 8.294,
#              'odd': 6.9078,
#              'doesnt': 7.1954,
#              'trap': 5.9915,
#              'hell': 5.7291,
#              'moskovit': 8.294,
#              'occup': 5.655,
#              'conduct': 6.9078,
#              'experi': 7.6009,
#              'pretend': 8.294,
#              'nobl': 8.294,
#              'goal': 6.0968,
#              'six': 8.294,
#              'command': 4.9982,
#              'master': 6.3481,
#              'thread': 4.1352,
#              'evolv': 7.1954,
#              'fallout': 8.294,
#              'nord': 4.6305,
#              'stream': 4.4874,
#              'conor': 8.294,
#              'gallagherseptemb': 8.294,
#              '2022': 3.7942,
#              'gallagh': 8.294,
#              'encircl': 4.4228,
#              'seriou': 6.0968,
#              'setback': 7.6009,
#              'largest': 6.3481,
#              'citi': 4.1044,
#              'earli': 6.6846,
#              'invas': 4.1832,
#              'src': 8.294,
#              'thestudyofwar': 6.2146,
#              'nytgraph': 8.294,
#              'european': 4.7975,
#              'extern': 8.294,
#              'servic': 5.2495,
#              'independ': 4.8929,
#              'cc': 7.6009,
#              'josepborrellf': 7.1954,
#              'huge': 5.8962,
#              'swath': 7.1954,
#              "there'": 6.2146,
#              'real': 5.0752,
#              'nazi': 5.2983,
#              'bloodi': 7.1954,
#              'z_game': 8.294,
#              'trust': 6.2146,
#              'god': 5.8962,
#              'trial': 7.1954,
#              'life': 5.0752,
#              'amaz': 6.9078,
#              'parent': 7.6009,
#              'afford': 8.294,
#              '8m': 8.294,
#              'car': 5.203,
#              'atlant': 7.6009,
#              'council': 5.116,
#              'denounc': 6.3481,
#              'imperi': 6.6846,
#              'larg': 5.655,
#              'saldo': 8.294,
#              'ruspuppet': 8.294,
#              'today': 4.1509,
#              'settlement': 5.8962,
#              'mykolaiv': 5.655,
#              'den_2042': 8.294,
#              'strang': 6.5023,
#              'show': 4.251,
#              'reflect': 7.6009,
#              'battlefield': 5.7291,
#              'mobil': 3.6497,
#              'loss': 5.1586,
#              'disconnect': 8.294,
#              'realiti': 6.3481,
#              'regim': 5.586,
#              'germani': 4.8929,
#              'weird': 6.6846,
#              "we'r": 6.6846,
#              'danger': 5.655,
#              'ball': 6.6846,
#              'american': 4.7105,
#              'hypocrisi': 7.1954,
#              'taiwan': 7.1954,
#              'persecut': 7.6009,
#              'ethnic': 5.8091,
#              'shell': 4.382,
#              'deserv': 6.6846,
#              'top10ap': 8.294,
#              'columbiabugl': 8.294,
#              'correctiona': 8.294,
#              'fledg': 8.294,
#              'invad': 4.8601,
#              'corrupt': 6.3481,
#              'aggress': 5.4608,
#              'power': 4.5099,
#              'baltic': 5.8091,
#              'friend': 5.8091,
#              'urma': 7.6009,
#              'reinsalu': 7.6009,
#              'republ': 5.4037,
#              'ukraine_world': 7.6009,
#              'let': 4.5328,
#              'interpret': 7.6009,
#              "biden'": 7.6009,
#              'respons': 4.6565,
#              'usnato': 7.1954,
#              'jam': 8.294,
#              'suffer': 5.4608,
#              'damag': 4.9618,
#              'agre': 5.8962,
#              'fate': 6.6846,
#              'confront': 6.9078,
#              'decid': 5.9915,
#              'firm': 6.6846,
#              'border': 4.4022,
#              'short': 6.2146,
#              'clip': 6.9078,
#              'uran6': 6.9078,
#              'mine': 5.8962,
#              'clear': 5.655,
#              'robot': 7.1954,
#              'goe': 5.8962,
#              'met': 6.6846,
#              'beneath': 8.294,
#              'audio': 6.9078,
#              'top': 6.6846,
#              'prioriti': 6.5023,
#              'nowukrainerussiawar': 8.294,
#              'defens': 4.251,
#              'individu': 7.1954,
#              'entiti': 6.6846,
#              'unilater': 8.294,
#              'rare': 6.6846,
#              'work': 4.3622,
#              '70': 6.9078,
#              'mlr': 6.0968,
#              'system': 4.6052,
#              'planet': 6.9078,
#              'york': 5.9915,
#              '15m': 7.6009,
#              'subject': 6.2146,
#              'robthomas14': 8.294,
#              'bordernick1': 8.294,
#              'jacothenorth': 8.294,
#              'notic': 6.6846,
#              'phoney': 8.294,
#              'robert': 7.6009,
#              'virtuesignal': 8.294,
#              "anywayhere'": 8.294,
#              'itppl': 8.294,
#              'meantim': 7.1954,
#              'stole': 8.294,
#              'even': 4.6052,
#              'idea': 6.5023,
#              'uniform': 6.6846,
#              'movi': 7.1954,
#              'wave': 7.1954,
#              'well': 4.5805,
#              'anxiou': 7.6009,
#              'angri': 7.1954,
#              'tear': 6.9078,
#              "kadyrov'": 8.294,
#              'silenc': 6.6846,
#              'memori': 6.6846,
#              'donbass': 5.655,
#              'tension': 6.6846,
#              'greet': 8.294,
#              'gift': 8.294,
#              'stabil': 7.1954,
#              'authoritarian': 8.294,
#              'endlessli': 8.294,
#              'inflict': 6.5023,
#              'upon': 6.9078,
#              'prison': 5.586,
#              'stop': 4.382,
#              'genevasummit': 8.294,
#              'alum': 8.294,
#              'navalni': 7.6009,
#              'poignantli': 8.294,
#              'opinion': 5.8962,
#              'read': 4.9268,
#              'ope': 7.6009,
#              'maria': 8.294,
#              'zakharova': 8.294,
#              'specul': 8.294,
#              'must': 4.0314,
#              'admit': 6.5023,
#              'unit': 3.7615,
#              'spoke': 8.294,
#              'promis': 6.9078,
#              '2': 4.1197,
#              'amnesti': 7.6009,
#              'intern': 5.203,
#              'zaporizhzhia': 4.2867,
#              'proof': 6.9078,
#              'utter': 8.294,
#              'disregard': 8.294,
#              'live': 4.3238,
#              'clash': 8.294,
#              'u': 6.2146,
#              'rat': 6.6846,
#              'rape': 7.1954,
#              'begir': 8.294,
#              'summer': 7.1954,
#              '23': 5.036,
#              'manhattan': 8.294,
#              'ride': 8.294,
#              'freedom': 6.2146,
#              'financi': 6.5023,
#              'caus': 5.2495,
#              'pocket': 6.5023,
#              'saw': 6.9078,
#              'caribean': 8.294,
#              'tax': 6.6846,
#              'heaven': 7.6009,
#              'secret': 6.0968,
#              'account': 6.0968,
#              'expos': 6.6846,
#              'pandora': 7.6009,
#              'paper': 5.8962,
#              'ampnato': 8.294,
#              'sold': 7.1954,
#              '3rd': 7.6009,
#              'countriesukrain': 8.294,
#              'guard': 5.5215,
#              'spot': 6.6846,
#              'two': 4.3428,
#              'silhouett': 8.294,
#              'shape': 7.6009,
#              'behind': 5.4037,
#              'wild': 7.6009,
#              'boar': 8.294,
#              'moldova': 8.294,
#              'young': 5.5215,
#              'draft': 5.036,
#              'age': 5.7291,
#              'getaway': 8.294,
#              'deni': 6.2146,
#              'blast': 6.5023,
#              'outright': 8.294,
#              'satan': 7.6009,
#              'secretari': 5.116,
#              'retak': 6.5023,
#              'blackmail': 6.9078,
#              'convey': 7.1954,
#              'ite': 5.8962,
#              'pedicabo': 5.8962,
#              'te': 5.8962,
#              'ipsum': 5.8962,
#              'latin': 5.8962,
#              'friday': 5.203,
#              'sever': 5.1586,
#              'joe': 5.8962,
#              "moscow'": 7.1954,
#              'fraudul': 7.6009,
#              'run': 4.9268,
#              'beschlossdc': 8.294,
#              'sitdown': 8.294,
#              'jordanbpeterson': 8.294,
#              'media': 4.8929,
#              'celebr': 5.8091,
#              'seek': 6.3481,
#              'offer': 5.9915,
#              'excus': 7.6009,
#              'scum': 6.9078,
#              'unequivoc': 6.6846,
#              'shout': 7.6009,
#              'gangster': 8.294,
#              'bulli': 6.6846,
#              'teenag': 8.294,
#              'postannex': 8.294,
#              'neighborhood': 7.6009,
#              'tragic': 7.1954,
#              'whistl': 8.294,
#              'walk': 6.9078,
#              'cemeteri': 8.294,
#              'bad': 6.0968,
#              'await': 7.6009,
#              'awar': 7.6009,
#              'livabl': 8.294,
#              'stoltenberg': 5.9915,
#              'agenc': 5.586,
#              'coincid': 7.1954,
#              'victori': 4.7975,
#              'shambol': 8.294,
#              'tweet': 5.7291,
#              '15pc': 8.294,
#              'noahmurphynft': 8.294,
#              'promot': 7.1954,
#              'nft': 8.294,
#              'project': 6.6846,
#              'childen': 8.294,
#              'women': 5.655,
#              'mean': 4.7975,
#              'lot': 5.116,
#              'center': 5.3496,
#              'sabotag': 4.5328,
#              'fear': 5.4608,
#              'woke': 7.6009,
#              'alex': 7.6009,
#              'christofor': 7.6009,
#              'breakingrussia': 8.294,
#              'partli': 7.6009,
#              ...})

# %% [markdown]
# Ranking the documents

# %%
def rank_documents(terms, docs, index, idf, tf):
    doc_vectors = defaultdict(lambda: [0] * len(terms))
    query_vector = [0] * len(terms)

    query_terms_count = collections.Counter(terms)
    
    query_norm = la.norm(list(query_terms_count.values()))
    
    
    for termIndex, term in enumerate(terms):
        if term not in index:
            continue

        query_vector[termIndex] = query_terms_count[term] / query_norm * idf[term]

        for doc_index, doc in enumerate(index[term]):
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] *idf[term]

    doc_scores = [[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items()]
    doc_scores.sort(reverse=True)
    
    result_docs = [x[1] for x in doc_scores]
    if len(result_docs) == 0:
        print("No results found, try again")
        query = input()
        docs = search_tf_idf(query, index)
    return result_docs, doc_vectors

# %%
def search_tf_idf(query, index):
    query = build_terms_query(query) 
    docs = None
    for term in query:
        try:
            term_docs = set(index[term]) 
            #print(term, len(term_docs))
            if docs is None:
                docs = term_docs
               
            else:
                docs = docs.intersection(term_docs)
                
        except KeyError:
            # Term is not in index
            pass

    docs = list(docs)
   
    ranked_docs, doc_vectors = rank_documents(query, docs, index, idf, tf)
    return ranked_docs, doc_vectors

# %%
# Then, perform a query and rank the documents
query = 'putin'

ranked_docs, doc_vectors = search_tf_idf(query, total_index)

# Display the top-ranked documents with their tweet text
top = 10
print("\n======================\nSample of {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
for doc_id in ranked_docs[:top]:
    print("tweet_id= {} - Text: {}".format(doc_id, tweet_dicts[int(doc_id)]['Tweet Text']))
# Out:
# ======================
# Sample of 10 results out of 414 for the searched query:
#
# tweet_id= 1070 - Text: ['lot', 'blood', 'putin', 'hand', 'putin', 'destroy', 'russia', 'putin', 'destroy', 'ukrain', 'putin', 'lost', 'war']
# tweet_id= 3046 - Text: ['would', 'putin']
# tweet_id= 736 - Text: ['putin', 'arriv']
# tweet_id= 3563 - Text: ['putin', 'mysteri', 'limp', 'russia', 'presid', 'realli', 'die', 'putin', 'health', 'analys', 'vladimir', 'putin', 'sick']
# tweet_id= 2593 - Text: ['putin', 'mysteri', 'limp', 'russia', 'presid', 'realli', 'die', 'putin', 'health', 'analys', 'vladimir', 'putin', 'sick']
# tweet_id= 1735 - Text: ['putin', 'mysteri', 'limp', 'russia', 'presid', 'realli', 'die', 'putin', 'health', 'analys', 'vladimir', 'putin', 'sick']
# tweet_id= 1619 - Text: ['putin', 'mysteri', 'limp', 'russia', 'presid', 'realli', 'die', 'putin', 'health', 'analys', 'vladimir', 'putin', 'sick']
# tweet_id= 765 - Text: ['putin', 'mysteri', 'limp', 'russia', 'presid', 'realli', 'die', 'putin', 'health', 'analys', 'vladimir', 'putin', 'sick']
# tweet_id= 3940 - Text: ['hitler', 'stop', 'putin']
# tweet_id= 3936 - Text: ['lukashenko', 'putin', 'clown']

# %% [markdown]
# **Evaluation**

# %%
search_results = pd.read_csv("./Evaluation_gt.csv")
search_results.head()
# Out:
#         doc query_id  label
# 0  doc_2052       Q3      1
# 1   doc_164       Q3      1
# 2   doc_411       Q3      1
# 3  doc_1805       Q3      1
# 4  doc_3442       Q3      1

# %% [markdown]
# 1. Baseline evaluation

# %% [markdown]
# a. Information need 1: What is the discussion regarding a tank in Kharkiv?

# %%
# Then, perform a query and rank the documents
query = 'tank in Kharkiv'

ranked_docs, doc_vectors = search_tf_idf(query, total_index)

# Display the top-ranked documents with their tweet text
top = 10
print("\n======================\nSample of {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
for doc_id in ranked_docs[:top]:
    print("tweet_id= {} - Text: {}".format(doc_id, tweet_dicts[int(doc_id)]['Tweet Text']))
# Out:
# ======================
# Sample of 10 results out of 6 for the searched query:
#
# tweet_id= 2233 - Text: ['destroy', 'ukrainian', 'tank', 'kharkiv', 'region']
# tweet_id= 591 - Text: ['footag', 'russian', 'tank', 'knock', 'ukrainian', 'forc', "ol'hivka", 'kharkiv', 'oblast']
# tweet_id= 1927 - Text: ['ukrainian', 'soldier', 'pose', 'front', 'destroy', 'russian', 'armi', 't72b3', 'main', 'battl', 'tank', 'kharkiv', 'oblast']
# tweet_id= 2700 - Text: ['kharkiv', 'region', 'air', 'reconnaiss', 'state', 'border', 'servic', 'elimin', 'tank', 'tigr', 'armor', 'vehicl', 'two', 'truck']
# tweet_id= 1969 - Text: ['ukrainian', 'forc', 'find', 'two', 'abandon', 'russian', 'armi', 'main', 'battl', 'tank', 'kharkiv', 'oblast', 'one', 't80bv', 't80u']
# tweet_id= 3477 - Text: ['russian', 'troop', 'hit', 'manufactur', 'workshop', 'armour', 'vehicl', 'plant', 'near', 'kharkiv', 'storag', '90', 'tank', 'vehicl', 'afu', 'also', 'vehicl', 'repair', 'point', 'energomekhkomplekt', 'plant', 'hit', 'zaporizhy', 'russian', 'mod']

# %% [markdown]
# b. Information Need 2: What discussions are there about the Nord Stream pipeline?

# %%
# Then, perform a query and rank the documents
query = 'the Nord Stream pipeline'

ranked_docs, doc_vectors = search_tf_idf(query, total_index)

# Display the top-ranked documents with their tweet text
top = 10
print("\n======================\nSample of {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
for doc_id in ranked_docs[:top]:
    print(doc_id)
    print("tweet_id= {} - Text: {}".format(doc_id, tweet_dicts[int(doc_id)]['Tweet Text']))
# Out:
# ======================
# Sample of 10 results out of 18 for the searched query:
#
# 622
# tweet_id= 622 - Text: ['putin', 'anglosaxon', 'blew', 'nord', 'stream', 'pipelin']
# 617
# tweet_id= 617 - Text: ["anglosaxon'", 'blew', 'nord', 'stream', 'pipelin', 'putin']
# 1451
# tweet_id= 1451 - Text: ['moscow', 'insist', 'probe', 'circumst', 'unpreced', 'attack', 'russian', 'nord', 'stream', 'nord', 'stream', '2', 'ga', 'pipelin']
# 3420
# tweet_id= 3420 - Text: ['whodunnit', 'fact', 'relat', 'sabotag', 'attack', 'nord', 'stream', 'pipelin']
# 2907
# tweet_id= 2907 - Text: ['sabotag', 'caus', 'destruct', 'string', 'nord', 'stream', 'nord', 'stream', '2', 'ga', 'pipelin', 'could', 'lead', 'escal', 'even', 'war', 'former', 'us', 'presid', 'donald', 'trump']
# 3343
# tweet_id= 3343 - Text: ['polish', 'member', 'european', 'parliament', 'say', 'us', 'blew', 'nord', 'stream', 'pipelin']
# 2676
# tweet_id= 2676 - Text: ['opinion', 'russia', 'like', 'culprit', 'nord', 'stream', 'pipelin', 'sabotag', 'washington', 'post']
# 3912
# tweet_id= 3912 - Text: ['swedish', 'militari', 'show', 'new', 'footag', 'largescal', 'leak', 'nord', 'stream', 'ga', 'pipelin']
# 3035
# tweet_id= 3035 - Text: ['europ', 'cri', 'sabotag', 'explos', 'rock', 'nord', 'stream', 'ga', 'pipelin', 'whatev', 'take']
# 849
# tweet_id= 849 - Text: ['west', 'behind', "'terrorist", "act'", 'nord', 'stream', 'ga', 'pipelin', 'say', 'russian', 'spi', 'chief']

# %% [markdown]
# c. Information need 3: What is being said about the annexation of territories by Russia?

# %%
# Then, perform a query and rank the documents
query = 'the Nord Stream pipeline'

ranked_docs, doc_vectors = search_tf_idf(query, total_index)

# Display the top-ranked documents with their tweet text
top = 10
print("\n======================\nSample of {} results out of {} for the searched query:\n".format(top, len(ranked_docs)))
for doc_id in ranked_docs[:top]:
    print("tweet_id= {} - Text: {}".format(doc_id, tweet_dicts[int(doc_id)]['Tweet Text']))
# Out:
# ======================
# Sample of 10 results out of 18 for the searched query:
#
# tweet_id= 622 - Text: ['putin', 'anglosaxon', 'blew', 'nord', 'stream', 'pipelin']
# tweet_id= 617 - Text: ["anglosaxon'", 'blew', 'nord', 'stream', 'pipelin', 'putin']
# tweet_id= 1451 - Text: ['moscow', 'insist', 'probe', 'circumst', 'unpreced', 'attack', 'russian', 'nord', 'stream', 'nord', 'stream', '2', 'ga', 'pipelin']
# tweet_id= 3420 - Text: ['whodunnit', 'fact', 'relat', 'sabotag', 'attack', 'nord', 'stream', 'pipelin']
# tweet_id= 2907 - Text: ['sabotag', 'caus', 'destruct', 'string', 'nord', 'stream', 'nord', 'stream', '2', 'ga', 'pipelin', 'could', 'lead', 'escal', 'even', 'war', 'former', 'us', 'presid', 'donald', 'trump']
# tweet_id= 3343 - Text: ['polish', 'member', 'european', 'parliament', 'say', 'us', 'blew', 'nord', 'stream', 'pipelin']
# tweet_id= 2676 - Text: ['opinion', 'russia', 'like', 'culprit', 'nord', 'stream', 'pipelin', 'sabotag', 'washington', 'post']
# tweet_id= 3912 - Text: ['swedish', 'militari', 'show', 'new', 'footag', 'largescal', 'leak', 'nord', 'stream', 'ga', 'pipelin']
# tweet_id= 3035 - Text: ['europ', 'cri', 'sabotag', 'explos', 'rock', 'nord', 'stream', 'ga', 'pipelin', 'whatev', 'take']
# tweet_id= 849 - Text: ['west', 'behind', "'terrorist", "act'", 'nord', 'stream', 'ga', 'pipelin', 'say', 'russian', 'spi', 'chief']

# %% [markdown]
# 2. Binary relevance

# %%
print_result = search_results["label"].unique()
print("The ground truth of our dataset is composed of {} Relevance Levels: {}".format(len(print_result), sorted(print_result)))

search_results["is_relevant"] = search_results["label"].apply(lambda y: 1 if y == 1 else 0)
search_results.head()

# 1. "Ukraine and Russia"
query = "Ukraine and Russia"
#
# Out:
# The ground truth of our dataset is composed of 2 Relevance Levels: [0, 1]

# %% [markdown]
# 3. Evaluate your algorithm by using different evaluation techniques

# %% [markdown]
# R@K

# %%
def recall_at_k(label, y_score, k=10):
    order = np.argsort(y_score)[::-1]
    doc_score = np.take(label, order[:k])
    relevant = sum(label == 1)
    return float(sum(doc_score)) / relevant

current_query = 0
current_query_res = search_results[search_results["query_id"] == current_query]

k = 5
#print("==> Recall@{}: \n".format(k, recall_at_k(current_query_res["is_relevant"], current_query_res["predicted_relevance"], k)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10340\4179577511.py in <module>
#       9
#      10 k = 5
# ---> 11 print("==> Recall@{}: \n".format(k, recall_at_k(current_query_res["is_relevant"], k)))
#
# ~\AppData\Local\Temp\ipykernel_10340\4179577511.py in recall_at_k(label, y_score, k)
#       1 def recall_at_k(label, y_score, k=10):
#       2     order = np.argsort(y_score)[::-1]
# ----> 3     doc_score = np.take(label, order[:k])
#       4     relevant = sum(label == 1)
#       5     return float(sum(doc_score)) / relevant
#
# <__array_function__ internals> in take(*args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in take(a, indices, axis, out, mode)
#     188            [5, 7]])
#     189     """
# --> 190     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     191
#     192
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in take(self, indices, axis, is_copy, **kwargs)
#     905
#     906         indices = ensure_platform_int(indices)
# --> 907         new_index = self.index.take(indices)
#     908         new_values = self._values.take(indices)
#     909
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1119         values = self._values
#    1120         if isinstance(values, np.ndarray):
# -> 1121             taken = algos.take(
#    1122                 values, indices, allow_fill=allow_fill, fill_value=self._na_value
#    1123             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\algorithms.py in take(arr, indices, axis, allow_fill, fill_value)
#    1447     else:
#    1448         # NumPy style
# -> 1449         result = arr.take(indices, axis=axis)
#    1450     return result
#    1451
#
# IndexError: cannot do a non-empty take from an empty axes.

# %% [markdown]
# P@K

# %%
def precision_at_k(label, y_score, k=10):

    order = np.argsort(y_score)[::-1]
    doc_score = np.take(label, order[:k])
    relevant = sum(label == 1)
    return float(relevant) / k

# Check for query 0

current_query = 0
current_query_res = search_results[search_results["query_id"] == current_query]

k = 5
#print("==> Precision@{}: {}\n".format(k, precision_at_k(current_query_res["is_relevant"], current_query_res["predicted_relevance"], k)))
print("\nCheck on the dataset sorted by score:\n")
#current_query_res.sort_values("score", ascending=False).head(k)
current_query_res.sort_values("predicted_relevance", ascending=False).head(k)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predicted_relevance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10340\4053999480.py in <module>
#      12
#      13 k = 5
# ---> 14 print("==> Precision@{}: {}\n".format(k, precision_at_k(current_query_res["is_relevant"], current_query_res["predicted_relevance"], k)))
#      15 print("\nCheck on the dataset sorted by score:\n")
#      16 #current_query_res.sort_values("score", ascending=False).head(k)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'predicted_relevance'

# %% [markdown]
# F1-Score@K

# %%
def f1_score_at_k(label, y_score, k=10):
    precision = precision_at_k(label, y_score, k)
    recall = recall_at_k(label, y_score, k)
    
    if precision + recall == 0:
        return 0.0
    
    return 2 * (precision * recall) / (precision + recall)

# %%
current_query = 0
current_query_res = search_results[search_results["query_id"] == current_query]

k = 5
f1_score = f1_score_at_k(current_query_res["is_relevant"], current_query_res["predicted_relevance"], k)
print("==> F1-Score@{}: {}\n".format(k, f1_score))

# %% [markdown]
# AP@K

# %%
def avg_precision_at_k(label, y_score, k=10):

    gtp = np.sum(label == 1)
    order = np.argsort(y_score)[::-1]
    doc_score = np.take(label, order[:k])
    ## if all documents are not relevant
    if gtp == 0:
        return 0
    n_relevant_at_i = 0
    prec_at_i = 0
    for i in range(len(label)):
        if doc_score[i] == 1:
            n_relevant_at_i += 1
            prec_at_i += n_relevant_at_i / (i + 1)
    return prec_at_i / gtp

# %%
avg_precision_at_k(np.array(current_query_res["is_relevant"]), np.array(current_query_res["predicted_relevance"]), 150)

# %% [markdown]
# mAP

# %%
def map_at_k(search_res, k=10):

    avp = []
    for q in search_res["query_id"].unique():  # loop over all query id
        curr_data = search_res[search_res["query_id"] == q]  # select data for current query
        avp.append(avg_precision_at_k(np.array(curr_data["is_relevant"]),
                   np.array(curr_data["predicted_relevance"]), k))  #append average precision for current query
    return np.sum(avp) / len(avp), avp  # return mean average precision

# %%
map_k, avp = map_at_k(search_results, 10)
map_k

# %% [markdown]
# MRR

# %%
def rr_at_k(doc_score, y_score, k=10):


    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    doc_score = np.take(doc_score, order[
                             :k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    if np.sum(doc_score) == 0:  # if there are not relevant doCument return 0
        return 0
    return 1 / (np.argmax(doc_score == 1) + 1)  # hint: to get the position of the first relevant document use "np.argmax"

# %% [markdown]
# NDCG

# %%
def dcg_at_k(doc_score, y_score, k=10):
    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    doc_score = np.take(doc_score, order[:k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    gain = 2 ** doc_score - 1  # Compute gain (use formula 7 above)
    discounts = np.log2(np.arange(len(doc_score)) + 2)  # Compute denominator
    return np.sum(gain / discounts)  #return dcg@k


def ndcg_at_k(doc_score, y_score, k=10):
    dcg_max = dcg_at_k(doc_score, doc_score, k)
    if not dcg_max:
        return 0
    return np.round(dcg_at_k(doc_score, y_score, k) / dcg_max, 4)

# %% [markdown]
# AVCJKHK

# %%
tfidf_array = np.array(doc_vectors)

# Check the shape of tfidf_array
print("Shape of tfidf_array:", tfidf_array.shape)

# Set an appropriate perplexity value
perplexity = 30  # You can adjust this value as needed

# Apply T-SNE for dimensionality reduction
model = TSNE(n_components=2, random_state=0)
np.set_printoptions(suppress=True)
model.fit_transform(tfidf_array)

# %%
# Scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], marker='o')

# Annotate each point with the corresponding tweet text
for i, txt in enumerate(tweets):
    plt.annotate(txt, (tsne_result[i, 0], tsne_result[i, 1]))

plt.title("T-SNE Visualization of Tweets")
plt.show()
